# %% [markdown]
# <div style="direction:ltr; line-height:300%; font-size:20px;">
#   <div style="text-align:center; font-size:20px;">
#     <br>
#     Advanced Information Retrieval Course
#     <br><br>
#     <b>Phase 1: Data Acquisition and Indexing Infrastructure</b>
#     <br><br>
#     Sharif University of Technology
#     <br>
#     Department of Computer Engineering
#     <br><br>
#   </div>
# </div>
# <div dir="ltr"></div>

# %% [markdown]
# # 🎯 Introduction
#
# Welcome to your project!
#
# ### Key Points:
# - **3 Phases**: Step-by-step progress.
# - **Dataset**: Scientific articles from [Semantic Scholar](https://www.semanticscholar.org/).
# - **Dataset Category**: `Artificial Intelligence & Bioinformatics`.
#
# By focusing on one domain, you'll boost the quality of your retrieval system.

# %% [markdown]
# # 🛠️ Phase 1: Building the Foundation
#
# The first phase is dedicated to laying the groundwork for a robust information retrieval system. This involves creating a reliable infrastructure for data processing and indexing, which ensures efficient and accurate retrieval of academic documents.
#
# ### Key Components
#
# - **📂 Data Preprocessing & Preparation:** Initial data ingestion and structuring of academic papers to facilitate efficient retrieval.
# - **🔍 Positional Index:** Development of a positional index to enable fast and precise document search capabilities.
# - **📊 Vector Space Models:** Implementation of various vector space models (`ltn-lnn`, `ltc-lnc`, `Okapi BM25`) for effective document ranking.
# - **📝 Spell Correction:** Integration of bigram-based spell correction to enhance search accuracy.
# - **📈 Performance Metrics:** Evaluation of system performance using metrics like MRR, Precision, Recall, F1 Score, MAP, and NDCG.

# %% [markdown]
# ### 🧹 Data Preprocessing & Preparation
#
# This step is crucial. Preprocessing your data correctly will make a significant difference in the effectiveness of your retrieval system.
#
# #### Steps:
# 1. **Read Data**: Load your dataset from the file.
# 2. **Preprocess**: Use libraries like [SpaCy](https://spacy.io/) and [NLTK](https://www.nltk.org/).
# 3. **Implement**: Create the `clean_data()` function:
#    - **Input**: Text (title or abstract).
#    - **Output**: List of valid tokens after lemmatization, stemming, and case folding.
# 4. **Clean Up**: Remove punctuation.
# 5. **Stop Words**: Identify and handle as instructed.

# %%
import nltk
from nltk.stem import SnowballStemmer
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize
from string import punctuation


def clean_data(text : str):
    """Preprocesses the text with tokenization, case folding, stemming and lemmatization, and punctuations

    Parameters
    ----------
    text : str
        The title or abstract of an article

    Returns
    -------
    list
        A list of tokens
    """    

    text = text.lower()    
    tokens = word_tokenize(text)
    tokens = [token for token in tokens if token not in punctuation]
    stemmer = SnowballStemmer(language='english')
    lemmatizer = WordNetLemmatizer()
    preprocessed_tokens = []
    
    for token in tokens:
        lemma = lemmatizer.lemmatize(token)
        stem = stemmer.stem(lemma)
        preprocessed_tokens.append(stem)
    
    return preprocessed_tokens


clean_data("An abstract is a summary of the main article.") # return ["an", "abstract", "is", "a", "summary", "of", "the", "main", "article"]
# Out:
# ['an', 'abstract', 'is', 'a', 'summari', 'of', 'the', 'main', 'articl']

# %% [markdown]
# ### Implementing Stop Word Removal
#
# Next, we'll implement the `find_stop_words()` function to identify and remove unnecessary tokens (stop words). Here’s how:
#
# - **Identify Frequent Tokens**: First, find the tokens that appear most frequently.
# - **Remove Top 30 Tokens**: Eliminate the 30 most frequent tokens from the entire text dataset. These are typically stop words that add little meaning.
# - **Output**: Print the stop words along with their frequency in any format.

# %%
import collections


def find_stop_words(all_text : list[str], num_token=20):
    """Detects stop-words

     Parameters
    ----------
    all_text : list of all tokens
        (result of clean_data(text) for all the text)

    Returns
    -------
    Return Value is optional but must print the stop words and number of their occurence
    """

    # TODO: find num_token top most repetitive terms and report them

    all_tokens = [item for sublist in all_text for item in (sublist if isinstance(sublist, list) else [sublist])]
    token_counts = collections.Counter(all_tokens)

    top_30_tokens = [token for token, count in token_counts.most_common(30)]
    top_30_tokens_count = [count for token, count in token_counts.most_common(30)]
    
    preprocessed_texts = []
    for tokens in all_text:
        filtered_tokens = [token for token in tokens if token not in top_30_tokens]
        preprocessed_texts.append(filtered_tokens)
    
    return preprocessed_texts, {key: value for key, value in zip(top_30_tokens, top_30_tokens_count)}


sample = [clean_data("An abstract is a summary of the main article.")]
find_stop_words(sample)
# Out:
# ([[]],
#  {'an': 1,
#   'abstract': 1,
#   'is': 1,
#   'a': 1,
#   'summari': 1,
#   'of': 1,
#   'the': 1,
#   'main': 1,
#   'articl': 1})

# %%
# TODO: read data file and do the preprocessing on the data (first clean the data and then detect and delete stop words)
import csv
import collections

def get_filtered_tokens(all_tokens, excluded_tokens):
    filtered_tokens = []
    for tokens in all_tokens:
        to_keep_tokens = [token for token in tokens if token not in excluded_tokens]
        filtered_tokens.append(to_keep_tokens)
    return filtered_tokens

all_titles = collections.defaultdict(str)
all_abstracts = collections.defaultdict(str)

all_paper_ids = []
all_abstract_tokens = []
all_title_tokens = []

with open('AI & Bioinformatics/data.csv', 'r') as file:
    reader = csv.DictReader(file)
    for row in reader:
        title = row['title']
        abstract = row['abstract']
        paper_id = row['paperId']
        
        all_titles[paper_id] = title
        all_abstracts[paper_id] = abstract
        
        title_tokens = clean_data(title)
        abstract_tokens = clean_data(abstract)
        
        all_paper_ids.append(paper_id)
        all_title_tokens.append(title_tokens)
        all_abstract_tokens.append(abstract_tokens)
        
all_data = list(all_titles.values()) + list(all_abstracts.values())
all_tokens, top_30_tokens = find_stop_words(all_title_tokens + all_abstract_tokens, 10)
all_abstract_tokens = get_filtered_tokens(all_abstract_tokens, list(top_30_tokens.keys()))
all_title_tokens = get_filtered_tokens(all_title_tokens, list(top_30_tokens.keys()))

corpus = {}
for p, t, a in zip(all_paper_ids, all_title_tokens, all_abstract_tokens):
    corpus[p] = {
        'title': t,
        'abstract': a
    }

# %% [markdown]
# ### 🗂️ Indexing
#
# In this section, we'll build a **positional index** for the system. This index will allow for separate and differently scored searches on various parts of a document, such as the title or abstract.
#
# - **Build the Index**: Create an index that enables search across different document sections.
# - **Functionality**: For any given word, your index should allow you to find:
#   - The document IDs where the word appears.
#   - The exact positions of the word in each section (title and abstract).

# %%
from collections import defaultdict

def construct_positional_indexes(corpus):
    
    """
    Get processed data and insert words in that into a trie and construct postional_index and posting lists after wards.

    Parameters
    ----------
    corpus: str
        processed data 
    
    Return
    ----------
    docs: 
        list of docs with specificied id, title, abstract.
    """
    positional_index = defaultdict(lambda: defaultdict(lambda: {'title': [], 'abstract': []}))
    frequencies = defaultdict(int)
    for paper_id, details in corpus.items():
        title, abstract = details['title'], details['abstract']
        for position, token in enumerate(title):
            positional_index[token][paper_id]['title'].append(position)
            frequencies[token] += 1
    
        for position, token in enumerate(abstract):
            positional_index[token][paper_id]['abstract'].append(position)
            frequencies[token] += 1
            
    return frequencies, positional_index
frequencies, positional_index = construct_positional_indexes(corpus)

# %%
title_lengths = defaultdict(int)
abstract_lengths = defaultdict(int)
for paper_id, details in corpus.items():
    title_tokens, abstract_tokens = details['title'], details['abstract']
    title_lengths[paper_id] = len(title_tokens)
    abstract_lengths[paper_id] = len(abstract_tokens)

# %% [markdown]
# ### 🔍 Viewing the Posting List
#
# This section allows you to view the **posting list** of a word and its positions in each document section.
#
# - **Function `get_posting_list(word)`**:
#   - **Input**: A word.
#   - **Output**: A dictionary where:
#     - **Keys**: Document IDs where the word appears.
#     - **Values**: Another dictionary with keys `title` and `abstract`, each holding a list of positions where the word appears in the respective sections.

# %%
def get_posting_list(word : str):
    
    """ get posting_list of a word
    
        Parameters
        ----------
        word: str
             word we want to check

        Return
        ----------
        dict 
            posting list

    """
    posting_list = {}
    if word in positional_index:
        for paper_id in positional_index[word]:
            posting_list[paper_id] = {
                'title': positional_index[word][paper_id]['title'],
                'abstract': positional_index[word][paper_id]['abstract']
            }
            
    return posting_list

print('frequency: ', str(frequencies['analysi']))
get_posting_list('analysi')
# Out:
# frequency:  1779
# {'40ea606185b59cd07b456cb1022d64bf41f5538d': {'title': [0], 'abstract': []},
#  '22949b20aef8923833158eaf90cf7c20199fb6ec': {'title': [1], 'abstract': []},
#  '07738739f377504dd0169c4f4deea9d3a9579f92': {'title': [6], 'abstract': []},
#  '716c671a796970a65107b3f9bb5bf1d4349fb454': {'title': [], 'abstract': [52]},
#  '9e558853e823d7449ad4ae7244a004b173f33be3': {'title': [], 'abstract': [62]},
#  'f5ac55a80db574f768b6fc4f895f909281fce1da': {'title': [2], 'abstract': []},
#  '2b8461b865ba1ec87b44bd32f41397e6dea20cfb': {'title': [], 'abstract': [36]},
#  '0983d84234135aa07e15f50a6dcc570b5ffbfe3f': {'title': [],
#   'abstract': [79, 94, 178]},
#  '920b59dd282e001c8eb790b774cdcc8d2e3b7cde': {'title': [0],
#   'abstract': [66, 113]},
#  '8e11ef89ba00206665f39df4312154dfa75ce159': {'title': [12], 'abstract': []},
#  '624061063ec313dfd9df8b96ee53ffbca91a3246': {'title': [], 'abstract': [72]},
#  '1838c9215a2f8995c8723295ce3f76fec6e8e602': {'title': [], 'abstract': [125]},
#  '3e0ef6ec8e3052ad9c3b3601c7fe6fad047f50ee': {'title': [], 'abstract': [107]},
#  '38bde4bc0ec6c4ea4587696ca8a9458e0089d432': {'title': [], 'abstract': [64]},
#  'c418aee24c43426ba309be0a73409f2864067d15': {'title': [0], 'abstract': []},
#  '34d4eb4666a20f7e3fad689d7862959bd128130b': {'title': [2], 'abstract': []},
#  '55ca7a2d71f7b82313b3a67d1713caad92a83ecb': {'title': [],
#   'abstract': [22, 29, 50, 98, 123]},
#  'f3d3bed63fb51315e2726837363ab3c9e89769eb': {'title': [8], 'abstract': [89]},
#  '4b640d13c274f70a52dccf69c354046f84220f82': {'title': [],
#   'abstract': [129, 344, 578]},
#  '82a99e0d626847fadb6be938f979a4aec573e9a1': {'title': [], 'abstract': [63]},
#  '0774160909b1015b09669bfdb2b9a4018d078d22': {'title': [], 'abstract': [87]},
#  '2dccf95c6f6cd69ca9d73b4b65d4eaf0e6decaa6': {'title': [], 'abstract': [51]},
#  '1a3398b4263f19798371e4e9552efae732921e0d': {'title': [], 'abstract': [148]},
#  'd86d76b754603772eb1b69dbd543af300f7054f8': {'title': [],
#   'abstract': [54, 84, 90, 167]},
#  '84753a02f1ca122c49d3051ec1a2d865e9539ce3': {'title': [],
#   'abstract': [2, 10, 35, 45]},
#  '83ea1aa045ded3c03238850551652940fbfbd998': {'title': [], 'abstract': [60]},
#  '1a8523be5aa3f91877c831660410be7fd2e2bd00': {'title': [7],
#   'abstract': [21, 100]},
#  '7b5bdde13faf568509d13ff72c42d93d67d84ac6': {'title': [], 'abstract': [52]},
#  'c8263cca4b12734a12437e1d03ed26a012e2f282': {'title': [], 'abstract': [54]},
#  '2786f19fba700b549493aa80f8d94ac5681a83b0': {'title': [], 'abstract': [95]},
#  'e244a6118d085b9b82fb06abdc9e447b6d027d56': {'title': [], 'abstract': [87]},
#  'aea19083a2cd2f04cd7a3dedbbc8fd3fdc064e9a': {'title': [], 'abstract': [141]},
#  '72685ae6f4753dbeeafa57bb3adc5e904197371e': {'title': [],
#   'abstract': [134, 216]},
#  '0aa54d5b94e40e1c1f313e3cfb7ba22a6bc64330': {'title': [],
#   'abstract': [65, 129]},
#  '71720542c83a21b50b03465203add32091da2deb': {'title': [],
#   'abstract': [8, 42]},
#  'e0b83d35795e179729b3ca0f53e29443577fd2b0': {'title': [], 'abstract': [16]},
#  '9c86c125e7e1c28a5075a984d6d9be20e8c77dc4': {'title': [],
#   'abstract': [61, 88]},
#  '8fb22a243def917a0ffd45a8a302b977b4e65117': {'title': [], 'abstract': [6]},
#  '8bcd93fc51b9cf06b4ad3ca7971b1654be17110d': {'title': [], 'abstract': [74]},
#  'ef6afa28ba6b53111af1a4df6dbb61739f3f09ec': {'title': [], 'abstract': [101]},
#  '080e4b7ddd0935f72aafd47e6ab8da4ee36fe464': {'title': [1],
#   'abstract': [0, 34, 42, 116, 119]},
#  '653b6f7c814b3f29fe048796f40e5fdadc2fd4b2': {'title': [7], 'abstract': [94]},
#  '732c82945bae56b822f5d89670ca4e48ca50dcfb': {'title': [], 'abstract': [130]},
#  '576b29da7c239164ec37775d4e11b053db8ccd9e': {'title': [], 'abstract': [117]},
#  '11ff7bd806f19a28977a697761cac3a428513dc3': {'title': [], 'abstract': [257]},
#  'c188aea2f47a2a54fb9ac9f56d7e2e186d5aaac6': {'title': [],
#   'abstract': [116, 128, 143]},
#  'b3066bc62827c78408d702641420c822aa90b516': {'title': [], 'abstract': [66]},
#  '415c8c94e96fcb7f29e05edfc95724f1c92c9c03': {'title': [],
#   'abstract': [95, 155]},
#  'cbbd93e3a4cd564b65831f7985b4b8f928dea09d': {'title': [], 'abstract': [32]},
#  '2011c02ffb4ae285b04f19b5873285ae16ac35d0': {'title': [], 'abstract': [87]},
#  'a70375041e48cdef25e8f41323c3d38d2f8e4df1': {'title': [1], 'abstract': []},
#  '0be3a7b07c7ac2f1130e2cb22c4bdb03d3c25f60': {'title': [], 'abstract': [58]},
#  'bcf919a6901d8139b9ecda5f663892bcf0adaf72': {'title': [], 'abstract': [84]},
#  '160d49481bc826b2fe088e93fe7a982b8fcf661f': {'title': [],
#   'abstract': [26, 98, 116]},
#  'befe794c29e0fe10d836789b358c65b049435692': {'title': [11],
#   'abstract': [39, 77]},
#  '1749d08104ef63bece5fd82f9bbf2cc6577dfa44': {'title': [3], 'abstract': []},
#  'd04faf012c54ed0b0db56648a8963702a9f8c819': {'title': [3], 'abstract': []},
#  '62ac09096c894f17602a73977123a66921a291a8': {'title': [], 'abstract': [29]},
#  '78de1bbfc6c699390663e8990b285e60bba6e929': {'title': [], 'abstract': [76]},
#  'e6c4293a92d50889eb202e49f85ef94dbb5f8afd': {'title': [],
#   'abstract': [40, 200, 209, 230]},
#  '0cbc480e0d380bbaa04bfb21a396c9e8da6e930e': {'title': [1],
#   'abstract': [4, 25, 93]},
#  '41382835ae60fb3280ea9a5b3004a236af1eb01b': {'title': [], 'abstract': [55]},
#  '23c4a00d97f5ef12014bd8c53e87afebd2b79878': {'title': [], 'abstract': [107]},
#  '5610dbb99cef1de553a62fd977e579dd2af93e95': {'title': [], 'abstract': [32]},
#  'bcab5f143ff93da892b56dcc17e049442818d298': {'title': [3], 'abstract': []},
#  'da530d81692c1147ee8cbac23c5b45bfe07a3b01': {'title': [1], 'abstract': []},
#  '871057177837ffacc315d31bb9f2dcaa705a0ff0': {'title': [1],
#   'abstract': [50, 162, 164, 208]},
#  '1cc4566ad023f7eb1f00250f73018b3de1bbd179': {'title': [5],
#   'abstract': [8, 28, 70]},
#  'fc8a3993ad3b1637b0cf0a70f804076c491999e5': {'title': [], 'abstract': [92]},
#  '8b7dcd6dbdca89da82e5ab97e398e557b02bf367': {'title': [4], 'abstract': [28]},
#  'f1330e04e70a5ce01afba2913ae087bf980d2a14': {'title': [], 'abstract': [112]},
#  '25fcf6c8325a408c072f18f84c21c8b946408df3': {'title': [], 'abstract': [152]},
#  '3cbe56f2bedf0e6a6dd68db30741e7378c984210': {'title': [], 'abstract': [157]},
#  '75f99e0d7287ca27fbe2f021d11d079bda647a27': {'title': [], 'abstract': [121]},
#  '35c6794b2d6c8aa2a4070588d281e5f73cf1fd80': {'title': [0], 'abstract': []},
#  '13a7ce1536ff5cf917671859857ebb74aae94a5c': {'title': [],
#   'abstract': [62, 128]},
#  '5e354707a3f01079264a626bd8eacb999d2b063a': {'title': [], 'abstract': [126]},
#  'dc45f718f4345396933c7066f82247eb400b970c': {'title': [3], 'abstract': []},
#  '11b463df037b9953471c5e6688b20611b0b5a11f': {'title': [8], 'abstract': [11]},
#  '1a0e0ad2860b900d5c79b4712233acfe32a1184f': {'title': [],
#   'abstract': [116, 120]},
#  '66101d54e5a27fb26c6654039fa815044191114d': {'title': [], 'abstract': [56]},
#  '79fa1a2929a78fdfd4679fbcdeeb371b56b43084': {'title': [], 'abstract': [80]},
#  '56d74eceb52608b79404feed0cd67fd5eb4cfbef': {'title': [2], 'abstract': []},
#  '7451d83e3eac30ba719ecea9a051af33dd10fc66': {'title': [], 'abstract': [38]},
#  '26e9be87cf43cc4d8ff330e8a251f14a42867d65': {'title': [], 'abstract': [125]},
#  'e0b17f6a1e132e6abbd56488aa608ff4400e8ea3': {'title': [],
#   'abstract': [67, 76]},
#  '22d85a9ca8eb4ff98d1713e97a80070a3217da57': {'title': [], 'abstract': [46]},
#  '6b188d7075208f50c5efbe8d8e977e6eb2f3a760': {'title': [],
#   'abstract': [3, 14, 34, 88]},
#  '3fd94cd3ca5e2b2751b12d8e64d12a53cc893bfb': {'title': [], 'abstract': [76]},
#  '76697a39d31ba02353c8f85f781db82c2178634d': {'title': [0], 'abstract': []},
#  '16bb78b4118ec178bdfb006a0f87902c77a2b80d': {'title': [], 'abstract': [59]},
#  'e32e2068310f5f525df06518a212525acc256d80': {'title': [], 'abstract': [50]},
#  '0f8bfe999609e16561ad3826762eb85419a4c1ee': {'title': [2], 'abstract': [56]},
#  '404d3c1a5c58a940644a9b7fe4d1c63f59281d9a': {'title': [], 'abstract': [45]},
#  'd55ce69944f65cf0a45df128c6df641d2ca9bb62': {'title': [1],
#   'abstract': [53, 56, 61]},
#  '03bf39a05be59ece8b6a968be9f278469320e131': {'title': [], 'abstract': [99]},
#  '3bba864c81aff7d3ea10de1ee321ad885ed4cf62': {'title': [],
#   'abstract': [2, 69]},
#  '43f8a2fac66b3f0a3658c38dd48e9ad914e3c37d': {'title': [], 'abstract': [19]},
#  '916fe86179a1a511a44f6eb72663e253d17f4403': {'title': [2],
#   'abstract': [22, 29, 107]},
#  '9e14d3b635718e8793375d869a16d2c04f1b3be7': {'title': [],
#   'abstract': [13, 30]},
#  '349e21ebc5badf1b08476efebf912eae49bbc55b': {'title': [1], 'abstract': [35]},
#  'aa8b2bc2738a719f3d2ccb1f1c1bc059da2281c5': {'title': [], 'abstract': [150]},
#  '2e223d0dbf1975305782578e520f7103154acf40': {'title': [2], 'abstract': []},
#  '2749975ade22c31c4e35d97afcf62c749235e9f3': {'title': [],
#   'abstract': [16, 64]},
#  '74487ea7c7a27a1a45c5a4dc306aea47cef0238d': {'title': [], 'abstract': [98]},
#  '45f9749adc798206a5e20a5b07526df936f6a02a': {'title': [2], 'abstract': []},
#  'd828f75b28ce32e5c5fe44ee5201b302b6e47009': {'title': [], 'abstract': [70]},
#  '04915ea7f188d34cdeea5b69adb5b229f76a9025': {'title': [], 'abstract': [71]},
#  'f4cbcd2f494a38318dffd35e3711fd960a306d1f': {'title': [1], 'abstract': [29]},
#  '52d46d78c92ef91611113005949b40acc9661ab6': {'title': [], 'abstract': [51]},
#  '378370ff2d55513c41b4e3f4eb4d8d16db562b66': {'title': [], 'abstract': [63]},
#  '6d759293a5ef837fb597176dd4b565c92f6e4e24': {'title': [], 'abstract': [84]},
#  '11de6746fecd87ee36f44ca88f5796080683d0eb': {'title': [], 'abstract': [77]},
#  '0cc0727ac85d88cdd05b56884c42a512ee24eceb': {'title': [3],
#   'abstract': [3, 33, 95]},
#  '81b0e2e66c225a6d7c1782b9cbe3e4168a7e9118': {'title': [], 'abstract': [37]},
#  '521a184667eb607265bcbf5c876f132eba92553d': {'title': [],
#   'abstract': [55, 118, 124]},
#  'd638801cfc296104c12bb5b78d8c930c47aedb66': {'title': [9],
#   'abstract': [51, 76]},
#  'a0d176819a32b9b4d80348783a321cfd77e26386': {'title': [], 'abstract': [45]},
#  '639d581e0f26bddb99e3c5de4ea131bbf83da1e4': {'title': [4], 'abstract': []},
#  '1fa05952eb07d7f960441f445a0f7ade07a761ca': {'title': [], 'abstract': [44]},
#  '1d42b76bd45adb62621376e7b3f4b5a9cce644f3': {'title': [], 'abstract': [54]},
#  '117ad6bedf119d2f29850474e637b416fce8286b': {'title': [], 'abstract': [456]},
#  '0984dc7dcb8d6432cf55a64a62895b26cac5c921': {'title': [],
#   'abstract': [113, 123]},
#  '2f637468c7433db608203ce0ed63391b4f5653f0': {'title': [],
#   'abstract': [32, 96, 135]},
#  'd9e31f69b68563eb18c03aaa4f5c5f0664ba0ce6': {'title': [],
#   'abstract': [22, 64, 72, 78, 123, 148, 174]},
#  'a948d3854e9048e1a763e346f0d171f907539e7d': {'title': [0], 'abstract': []},
#  'ac666e4a17236d0120578267a20b1a488caebb66': {'title': [2],
#   'abstract': [34, 73, 82]},
#  '68c52619d6a12fcaa3f6207239d5c49f2ac1068e': {'title': [], 'abstract': [49]},
#  'e68db86ffd75305b101bbeca0ca6d898b503ab34': {'title': [1],
#   'abstract': [20, 84]},
#  '035b282ce1719f928d895a290284225197cc9eef': {'title': [2],
#   'abstract': [4, 64]},
#  'dd2bf41f260d7b9901d2b2006e06ac4317a237d7': {'title': [], 'abstract': [78]},
#  '6492bc0054f64d9c50240c2ec83d3953eec7782b': {'title': [3],
#   'abstract': [6, 21, 35]},
#  '800e25618ffbca9fe60003cbb13ea1e0fcb94aa1': {'title': [], 'abstract': [292]},
#  'a389216b359c706418bf6611ef63bb083c15e9cb': {'title': [], 'abstract': [50]},
#  'c7bb9458de0362c4a4132ac14d5f62d933fde12f': {'title': [],
#   'abstract': [109, 182]},
#  'c000ab19dd2aca7659394828deab5ce90cdd9c1d': {'title': [],
#   'abstract': [164, 185]},
#  'b3266cbc937ee738d0aed832888f81ff64761b72': {'title': [5],
#   'abstract': [39,
#    133,
#    151,
#    154,
#    169,
#    208,
#    223,
#    226,
#    316,
#    327,
#    330,
#    332,
#    343]},
#  '7afe3a449f0dd31ec08aa9748f94079684f899e6': {'title': [8],
#   'abstract': [27, 93]},
#  'cc915af93de509acd7588d54071fe0aa14645542': {'title': [],
#   'abstract': [101, 164, 169]},
#  '1e58920c4235fdbfc22534c92938f22d1728f0b9': {'title': [], 'abstract': [132]},
#  '981ab257c38daeb449ec05067407022a25040833': {'title': [], 'abstract': [17]},
#  'd3fa4692cf88116d911130225e0338f5bd4c8d5d': {'title': [], 'abstract': [4]},
#  '5ca69ef6e8de643e3443b7d92e9b6c4703d2d366': {'title': [7], 'abstract': []},
#  'bdf5f954369addc85bab3f42607bdcc2d6907a12': {'title': [],
#   'abstract': [56, 179, 215]},
#  '6e72d5b20d700a7fc321144d155603c343b80d81': {'title': [],
#   'abstract': [56, 72, 155]},
#  '6347869833b46b35c296c822298cff3e243ccfd7': {'title': [], 'abstract': [85]},
#  '3d2280c9d1286b6502a91e987e4f4d5ce7d81f8c': {'title': [], 'abstract': [121]},
#  '363df5950c4dfa02d5b3b63ddd6a5e27eb62d982': {'title': [],
#   'abstract': [53, 57]},
#  '1ba07035f83792154e77ed35d842e04de8a1eeeb': {'title': [], 'abstract': [32]},
#  '62f18f4e799eb7327a9ab0c418837e4f0de5fa29': {'title': [2], 'abstract': []},
#  '8799fdf3c80e1a256dd3b4d8b59feba44db892af': {'title': [], 'abstract': [64]},
#  '27a572eb66a5014f6f452d6567efbd43fb701292': {'title': [],
#   'abstract': [7, 55, 121]},
#  '7188ad76a69babef054769582a66cd7ad3b18ad8': {'title': [0], 'abstract': [3]},
#  '03fe0f0e2aca09d7e66a09170d8772ee8ebc030b': {'title': [], 'abstract': [98]},
#  '4d0506d3e7f5dd23e1620cf8c48650bf1552bd3e': {'title': [],
#   'abstract': [30, 88]},
#  '48d46a6a11f1111840204484dc51b88251951dfe': {'title': [], 'abstract': [114]},
#  'b9523a686d525541918a79cf68945f79e0ca5524': {'title': [],
#   'abstract': [71, 99]},
#  '5dd5a51bc83ded25d795f2dc2f4fbb2a722b40a7': {'title': [], 'abstract': [90]},
#  '486b23ad3956688a93d46e190f0dcbf843a2efd2': {'title': [13], 'abstract': []},
#  'e276500a8c948be62a0e6522a5b7936434e7ed97': {'title': [11],
#   'abstract': [50, 77, 91, 117]},
#  'f253334dc24ec7f58bf699cef075bda3f749ac29': {'title': [], 'abstract': [76]},
#  '48f8b22618c7da90c06bf08c66f9c3e950dc19dd': {'title': [],
#   'abstract': [73, 129]},
#  'fc8d741892643a58144678f1f04d52442cfdeb81': {'title': [], 'abstract': [106]},
#  '7c6a4a4a2f01254a0a4d4a9fb7556fff4a50c77f': {'title': [1], 'abstract': [96]},
#  '81787adce31228823f4da5c668bca93946d2da80': {'title': [],
#   'abstract': [37, 43, 50]},
#  'd29444b1873c206fba4ade481c33e9d80ecfb7c6': {'title': [],
#   'abstract': [4, 12]},
#  'e3d80e0159325a43b3f009809a8c72c794ad03d3': {'title': [], 'abstract': [80]},
#  '757afab929cef7394d5155d25dc98c2cb680a540': {'title': [], 'abstract': [40]},
#  '0fe4b59122bed00bd3962c92677d12443a3d8ab3': {'title': [], 'abstract': [108]},
#  '5fd5d17d599908ae1f35ab2024d73c3aebb52c47': {'title': [],
#   'abstract': [3, 34]},
#  '4ac38587a17417023420fa948ecc4d84e0322422': {'title': [],
#   'abstract': [15, 40, 120]},
#  'a0278083e066a3f2c4680f32a9778838c5b2c6b1': {'title': [1], 'abstract': []},
#  'a114acb9c90d29d9611674824b01a007b6b7a115': {'title': [], 'abstract': [26]},
#  '7139475591a8c70f5ed6d694da14d47e0e1d49e3': {'title': [], 'abstract': [63]},
#  '5f79dd94f87cefa5878c6438d60f92cd100726f9': {'title': [], 'abstract': [89]},
#  '83770872715b0376debe1d6e211977730496d095': {'title': [5],
#   'abstract': [43, 75, 143]},
#  '2e8dee1934d98cd4f80a2e9668720fb00e873999': {'title': [], 'abstract': [65]},
#  'e110b535a167ad0cb0670f6fe38df7015959d1eb': {'title': [],
#   'abstract': [25, 140, 161, 168]},
#  '2504203ba752c365f895e0180db3e24aeaf521e8': {'title': [6], 'abstract': [44]},
#  '4ab8987b5de0d7526ba77016add79eca41ad017b': {'title': [4],
#   'abstract': [1, 10, 73]},
#  '0d9ed06c7a4acb693140d08be35858b941775fd8': {'title': [], 'abstract': [55]},
#  '4093aa4165a33b52e3cbfd1dd5495c6357e71d24': {'title': [13], 'abstract': []},
#  '49e90a0110123d5644fb6840683e0a05d2f54371': {'title': [],
#   'abstract': [1, 15]},
#  '4182224ee383331db7e71eac129ae92853f4cc3e': {'title': [],
#   'abstract': [2, 27, 45]},
#  '94b69cf199fa0b6c842e17fe5d6174a9d161c3df': {'title': [], 'abstract': [60]},
#  '582b211587ee9ff9bf081c7cfee53a8923168b3a': {'title': [], 'abstract': [156]},
#  '2f50b9125e74a2d9b02dff9787fc9b73320a2a4a': {'title': [4], 'abstract': []},
#  'f0f741ba0be215916db310a124c0414e0d1b9bc9': {'title': [], 'abstract': [126]},
#  '984615bad2f281bdf0b75cbb7a64c064d9715346': {'title': [1], 'abstract': []},
#  'd1ae0a43e55e862fe2a3220b8bf0f92942617ffe': {'title': [], 'abstract': [170]},
#  'ddaf66fea177b84ebed3dfba4607566e7d9eda34': {'title': [8], 'abstract': [3]},
#  '9800d926b9b401f86c4541208b7c22d480478bbd': {'title': [], 'abstract': [2]},
#  'ca0b687b7bab17edfab161f07439a2eadd6721b2': {'title': [0], 'abstract': []},
#  'bf511f3e3850c465b7b110458586f94b14424e66': {'title': [], 'abstract': [63]},
#  'f50b442dbb47a9302925c4a53301d03d13671de5': {'title': [10], 'abstract': [57]},
#  '458dffde49f6018aaf8829d7ea6f3a0706e36940': {'title': [],
#   'abstract': [73, 184]},
#  '881bb1d8062529a8a6e42b85345ce99f6bf93175': {'title': [], 'abstract': [67]},
#  'f9f8b7a383a4b931731e090e46792cfae6398987': {'title': [], 'abstract': [172]},
#  'e51568a6fae870657335c12d2e12fc503ba7629e': {'title': [], 'abstract': [32]},
#  'ccaff780b9c28a405ff0475426698b55ab73a616': {'title': [], 'abstract': [78]},
#  '02152bd960cda593fc7103ce14cbce7b5c1cd91a': {'title': [1], 'abstract': []},
#  '4e1027255b0eba4212c2a168c9ac0a9e85aeca0d': {'title': [], 'abstract': [45]},
#  'b3175d5f365534d35c3fb453e52a05c6c2f0fe88': {'title': [1],
#   'abstract': [99, 174]},
#  'ad43250e78f573213a217348c582e740b80720df': {'title': [],
#   'abstract': [44, 122, 126]},
#  '3c61dc0cc5b86065bc2875d9c883dc18db0c1f5f': {'title': [12], 'abstract': []},
#  '0b3ef135ddcd92a6e1329b794a6637a902902cba': {'title': [], 'abstract': [130]},
#  '5411a036cb5757915f2268333b6caf91132867ad': {'title': [3],
#   'abstract': [66, 124]},
#  '1bcf7a643e704376981394d751b3f5f53ed2b93e': {'title': [], 'abstract': [143]},
#  '06125e72deed620a82d5cf7e06cd5d7a10fb55e8': {'title': [], 'abstract': [52]},
#  '6a5607f975bc5232f5aae4719de308a7e560794f': {'title': [1],
#   'abstract': [37, 183]},
#  '059fc89d90112f8881ae105af593a6a8f5b24a21': {'title': [], 'abstract': [27]},
#  'b6cfea3feb9e4bc43b91065bda20040dfe18aa75': {'title': [],
#   'abstract': [176, 183, 253]},
#  'bdfe1ce5bedc30169a1706a30988d560b1d16881': {'title': [], 'abstract': [86]},
#  '96f535751c4e6e4fe5f2cb00d186fedbad7efd71': {'title': [],
#   'abstract': [34, 107]},
#  'bb9abc47820df6ce0d122dc98d81958c015d306d': {'title': [], 'abstract': [94]},
#  '02a658b72ac5ae14ed57f34ba768cfabdd8cf89a': {'title': [], 'abstract': [3, 6]},
#  'cefa8bbc701175e2f5a272c2a7a2796d8169477f': {'title': [], 'abstract': [177]},
#  'a83e7e7aef637bae67012f8bcc70f8503489ae6f': {'title': [],
#   'abstract': [167, 206]},
#  'cf9f41b9bbd68168f3487fe75680962cfc699205': {'title': [],
#   'abstract': [10, 33]},
#  'e3d65e84209d2103d5bfb143497be67fcd86d2f1': {'title': [], 'abstract': [123]},
#  'f50b35343091ef1c4e8488f47c29a13549383642': {'title': [9],
#   'abstract': [51, 56, 79]},
#  '15fdb8d550e098be1387c8aae94308b9972e4593': {'title': [5], 'abstract': []},
#  '15c2cd4a98b0534a0236d82d54b7fbbd7e379848': {'title': [2], 'abstract': []},
#  'da94bf297921b74e56cdba38e510be66f58ebf80': {'title': [], 'abstract': [137]},
#  '5ba2218b708ca64ab556e39d5997202e012717d5': {'title': [], 'abstract': [77]},
#  '203cf56b8e1264dbc4d802a1d6b8f2ba7ac68024': {'title': [],
#   'abstract': [52, 100]},
#  '33dc2a148d05fbd391edc0efd8025e0b63ea0eb3': {'title': [11], 'abstract': []},
#  '4bef84421d4cbd027183edf694593897d001d195': {'title': [2], 'abstract': []},
#  '998f875e2ef73228020421ba8ef12e563a96fd30': {'title': [3], 'abstract': []},
#  '91472d0e5d8df4aeda744e209330fdf5292c2fc7': {'title': [],
#   'abstract': [18, 64]},
#  '9e5fac15b1ccdbd55c4a672e44667784a64e0074': {'title': [],
#   'abstract': [74, 79]},
#  '091a8d3719cbb493c8c23f456a46bb267d4a2c9e': {'title': [2], 'abstract': []},
#  '1d9e5364ec4cc7ab2cefcf6039384391b15f95d4': {'title': [0],
#   'abstract': [11, 38, 46, 83, 87]},
#  '13e8d1e05ea3a041a73387551dd267eb6855310b': {'title': [], 'abstract': [127]},
#  '2a2660e17102409d2b31abb28649e0fdde477001': {'title': [],
#   'abstract': [60, 64]},
#  '367a87885d12b28a3c95f81996f7e179deb4574b': {'title': [], 'abstract': [64]},
#  '3f530f9fd4b76cde051a07a1b15537c0a6bb9093': {'title': [],
#   'abstract': [23, 173]},
#  '0f6894b547489e1b07d0c4783947b814ac846a17': {'title': [], 'abstract': [106]},
#  'c8800e83fd2b5a2ae638bfddf616cfb0f48b31fa': {'title': [], 'abstract': [44]},
#  '33e0e8c533d9ccbaeef233a47cfdd447bee5f114': {'title': [2], 'abstract': [61]},
#  '21e944b2766eac8902a7b2604f6f6e82f1738a98': {'title': [], 'abstract': [146]},
#  'd07b5ba33322b1f29145f9856f2353dd257040e7': {'title': [0], 'abstract': []},
#  '8ed22252061615834932f4cb6e7a68e669593827': {'title': [1],
#   'abstract': [11, 14, 15, 27, 31, 40]},
#  '376330e1a7235cd7f401626509e0d07dd44bacdd': {'title': [4], 'abstract': []},
#  '54e0882f54de4503f04b8bfbd457e357ac236187': {'title': [1], 'abstract': []},
#  '2abde28f75a9135c8ed7c50ea16b7b9e49da0c09': {'title': [4], 'abstract': []},
#  '4512796aadafdc5921d4053cd04de42ab7b73514': {'title': [9], 'abstract': []},
#  '22f0b6f6d7091646408985f17e52fc709bc85dbe': {'title': [],
#   'abstract': [5, 28, 76, 85]},
#  'edcfbe1c9224cea69cb003f1f279e9084db4dff4': {'title': [2],
#   'abstract': [18, 33]},
#  'f1a36f8ef1e86f77774b245cf2d836b7ae73abdd': {'title': [], 'abstract': [78]},
#  '0a5a04368d2c161ea29f8d6da733c15bacba71a9': {'title': [2],
#   'abstract': [30, 62, 99, 139]},
#  '1d3485be8a6ca0ce83f2c9e968547cfc24240ed3': {'title': [],
#   'abstract': [61, 65]},
#  'd64d742d365c712aa92d00978da4dfca567b3eab': {'title': [], 'abstract': [95]},
#  'c9523eeedd16b47879e0428d940fc91cc4700c33': {'title': [1], 'abstract': []},
#  '380517b05ca816504116e4f62394602bba7091bd': {'title': [], 'abstract': [36]},
#  '2d4821e0e55c494a8e41c3f67c653f00bba1694d': {'title': [1], 'abstract': []},
#  '545d107cce78b907a22d7545f5dd61a8b44c38af': {'title': [], 'abstract': [138]},
#  '6ca58caf95e1e2d7c5ca3d675974f44175a07d3a': {'title': [],
#   'abstract': [74, 118]},
#  '42a719898ef837dbe5283007c5449ef893c3a8c7': {'title': [],
#   'abstract': [42, 81, 146]},
#  '41f2acdbef7b27f52184fe84ca10b818fd7fc19e': {'title': [], 'abstract': [69]},
#  'd6f849900ef3ff64d6185ded78ccea1a0d1283f5': {'title': [3], 'abstract': []},
#  '291c1274ee45bf78662ed60831ef1bdaf89bed94': {'title': [], 'abstract': [2]},
#  '19d1546aab3e95ef3d61a7fbda8e5143ad93b91c': {'title': [3], 'abstract': []},
#  '60c34a1ae08aefec26d2a1fbcf5b333a1de9a7ee': {'title': [], 'abstract': [4]},
#  '7d368cc2e23cb0ed54384c31c73b6f713a970085': {'title': [2],
#   'abstract': [62, 67]},
#  '507daa2212128a268ac4547cdbed0a10078fa038': {'title': [4], 'abstract': [44]},
#  '1b0923cd515529109499c624396a132651f9855f': {'title': [3], 'abstract': []},
#  '9d2bafd83b6433d80f421294f92784f54b210fb5': {'title': [2], 'abstract': []},
#  'a349f686da3a94cd180971d0aa7c1dddb7123392': {'title': [], 'abstract': [53]},
#  'be68e94f3c40831c4544caa965e8c8fef2828529': {'title': [3], 'abstract': []},
#  'f505853ee5d63df2c95919b3e01be258d313c4aa': {'title': [],
#   'abstract': [37, 45]},
#  'a77420871bb3ef75643dc50150ca52ebe707a8fc': {'title': [7], 'abstract': [59]},
#  '3e6c84302b2b56cf8369253d6168b852d0aa1fd6': {'title': [9],
#   'abstract': [40, 63, 96, 150]},
#  'eb58ab72ed27c25509b140f1a6db041d2cf5a22c': {'title': [11], 'abstract': []},
#  '4949dc142eaecd25b0793bf2c699d7e273d689e9': {'title': [1], 'abstract': []},
#  '97fb47a2da4d864a84ba8a741e35862fbe8e614d': {'title': [],
#   'abstract': [27, 33, 35, 67]},
#  '88f05cac1accc4f1883976763ea6fc3ae68b2084': {'title': [],
#   'abstract': [28, 120]},
#  '6d051b265d53481526051344e770455234281290': {'title': [], 'abstract': [160]},
#  '9ef234200193a2ba82d4ec7e9222facbb48e8c0c': {'title': [9], 'abstract': []},
#  'dcde6dd8ca7f57630818b8ea1b750919d32e6b00': {'title': [], 'abstract': [2]},
#  '5f374858285e268d38102a3bfdd536754755a6e2': {'title': [],
#   'abstract': [42, 110]},
#  'b0455fecbff609cda75ef997b6caf56f67c1a3ef': {'title': [], 'abstract': [112]},
#  '4db5004421cfa8ad750d1dab8d0ed11e83697b40': {'title': [],
#   'abstract': [42, 63, 122, 153]},
#  '73e3a9302448742fd89cdb7077e11cfbbb2bda42': {'title': [], 'abstract': [50]},
#  'aa50e40bb21fbbd645303974eb84e320aa150104': {'title': [4], 'abstract': []},
#  'e14f850080b7c565f21c10bcecd23f167d0f0eba': {'title': [4], 'abstract': [83]},
#  'ffadd3e0666613e5b082b432a7ebdbc4211b8022': {'title': [],
#   'abstract': [82, 118]},
#  '6f9996e1c821229aee053cfacf235da33a64d779': {'title': [], 'abstract': [81]},
#  'ad54c6ddc85fa2d3a3b2e7f96dac2305d17dd116': {'title': [],
#   'abstract': [67, 152]},
#  '4768327c650b945813f7c0d461d8305df0f562b3': {'title': [], 'abstract': [92]},
#  '5127759530ce213f488af2859190697770f557f3': {'title': [2],
#   'abstract': [5, 9, 29]},
#  '4054f15b807dcdc4d2112166f449d70ab7b1a8da': {'title': [], 'abstract': [77]},
#  'f215ce917c06fcfb21af5cc0283e008e6c391816': {'title': [],
#   'abstract': [88, 107]},
#  '1bc864447038f60ccd5928001d914932f543602d': {'title': [], 'abstract': [100]},
#  'b95d4aff1287a8c3f4bb78a659de9646059b36a5': {'title': [2], 'abstract': []},
#  'd65b72fa7fd095fb7bb7f782cc52665e88e0b423': {'title': [], 'abstract': [137]},
#  '7c79813665a2301d76e5cf0fb8ca357ca77cb923': {'title': [], 'abstract': [45]},
#  '1a442ec8ba0235c7180b29c39a507ee57841fd7b': {'title': [4],
#   'abstract': [36, 46, 69, 80]},
#  'e406e646fda9ffd80aaabb75fd113cb5c7edd024': {'title': [], 'abstract': [74]},
#  'd2d701911b04ee004d56a8d38382b7e1571d29bb': {'title': [],
#   'abstract': [40, 49, 64]},
#  '86f03f3de7ea1e1a6f96f5f5d835f629e31d89b3': {'title': [],
#   'abstract': [3, 39]},
#  '4923c573bf0af4b9b08de8093ad9c83e4ad02c18': {'title': [], 'abstract': [29]},
#  'aa7932d1002b8f9a1264df10f043744837e1cf23': {'title': [], 'abstract': [54]},
#  'c1153e719e169ab267d54d6ce82454080ffd24ed': {'title': [],
#   'abstract': [26, 59]},
#  'cc628fee1e83bfba1d581bfa128c9cb6c28ef8ad': {'title': [], 'abstract': [7]},
#  '40811edf4b0efe664676e83f703bbbe278c4ba58': {'title': [], 'abstract': [28]},
#  'f9eefe2f4cfc84fac0d14043e38e91aa46c5d064': {'title': [],
#   'abstract': [78, 103, 156, 172, 189, 216]},
#  'acf49229baff6154c4ac87fe691ef7076df5dfca': {'title': [], 'abstract': [92]},
#  'c99062d463a9c8f70274b6f7daabb4dee54aa978': {'title': [], 'abstract': [43]},
#  '85db300cb16c53a1fcc047c49309d2c1b7a25c84': {'title': [], 'abstract': [172]},
#  'ff6b9cc12f0a1f2350019551ab92802407730433': {'title': [],
#   'abstract': [266, 328]},
#  '721d0c5a193fb5b5c357ca56e20d28e1ef4c9ca7': {'title': [3], 'abstract': [5]},
#  '92ade1497d704e016c7fb85dc2d9c3122cf47188': {'title': [],
#   'abstract': [37, 123, 173, 186]},
#  'cb7f9efc0b2acab98f331e994032ae401fd60d8e': {'title': [],
#   'abstract': [55, 60, 67]},
#  '0f4cdaf07aaa72a1897a81009515cc02d4cb51d5': {'title': [], 'abstract': [42]},
#  '427016076630cd47205de94029521e74ea3ec754': {'title': [5], 'abstract': []},
#  'd3863d29a8799d966512150b750291555f4abf9f': {'title': [],
#   'abstract': [61, 111]},
#  '50560dd83bef7a7e12b8a1ab0af6d67218ed5e99': {'title': [],
#   'abstract': [66, 83, 85]},
#  '211fa0b6b835f68cf897cef702ead303ba658a14': {'title': [],
#   'abstract': [18, 56]},
#  '6412911acaec5512520efb12c927a197d0bae146': {'title': [10], 'abstract': []},
#  '7694f3254e3feab87aac11856cb6eb986a33ab5a': {'title': [2], 'abstract': []},
#  '9f77886045118e52ac9eb9ac49c8339bb40c88a2': {'title': [], 'abstract': [58]},
#  '69c1657c44e99be56b50464b5571cb540e8c3d74': {'title': [1], 'abstract': []},
#  'da78c2039c0360fd4edafdae0c942bd4b8bbf40e': {'title': [], 'abstract': [88]},
#  '713e881b5c3134debf934026edf6f0ba3cb42c3c': {'title': [],
#   'abstract': [9, 25, 70]},
#  'b08618311975beefb4647a9482b5f23ec65e2e39': {'title': [],
#   'abstract': [40, 155]},
#  'b88c11922cac84e5ea902f82d27ae21c3dda2e04': {'title': [], 'abstract': [54]},
#  '5d241eb11325c463859b17d7f6bc5c34e9000f69': {'title': [], 'abstract': [79]},
#  'dca272c97c1ddbf9e94dfa1169cc8f91665153fa': {'title': [],
#   'abstract': [99, 134]},
#  '75dd6e09e2a44c363bb50e463c812fd3393cbf1c': {'title': [5], 'abstract': []},
#  '40cec58d760940f62975e0d5e99632e28df0b5d0': {'title': [], 'abstract': [6]},
#  '4f206dca13d53fad63290866a76845e23db6c6d2': {'title': [],
#   'abstract': [53, 62]},
#  '1e8a5d2c359ead7ab2e55e1d492a7ed1e2808d0c': {'title': [], 'abstract': [68]},
#  'f7dc4ae4ff7b904b51699f9353b88f48950fa9f7': {'title': [], 'abstract': [76]},
#  'c52ac4c7655622d2f8c5b36bd2e0be9ad6536c02': {'title': [], 'abstract': [10]},
#  '2e5bd168a5489dfb1aeb7e5c4d5e67fbb3531fc6': {'title': [4],
#   'abstract': [6, 73, 75]},
#  '617f5216c4d7daf2b99aeb02fadbd0b66c297610': {'title': [6], 'abstract': []},
#  '77b33de7e0b04898c6aab48dcf77019f77c76276': {'title': [1], 'abstract': []},
#  '66f22519effe2ce935ba6b68b482379f25f6c107': {'title': [], 'abstract': [73]},
#  'bad5ffb4bb6960d02e9a3db443932bf10e0192f1': {'title': [], 'abstract': [93]},
#  '432015e247501b5f45865131de8eba2af2808026': {'title': [1], 'abstract': []},
#  'c166ff82675162cb5d4faed016258ec0623f4bc3': {'title': [],
#   'abstract': [112, 126]},
#  'da6a9ed89bcdf6aeaff377748f04026d94833f44': {'title': [], 'abstract': [175]},
#  'bb130ed8e9ea1f014e341fd955e672d48bcc64de': {'title': [2], 'abstract': [45]},
#  '7e77d2d973e4837da931a065de14aa5749208bd8': {'title': [],
#   'abstract': [58, 76]},
#  '90eab4f3fa9fc03ba6904a467b3a5675d951a072': {'title': [3], 'abstract': []},
#  'b3bca333e4090ae0971de9a3506cb602d99c6f02': {'title': [1],
#   'abstract': [19, 100, 162]},
#  'db588139f03b0af57b89e22025a7d5dfffa971df': {'title': [], 'abstract': [73]},
#  '5b1c985d5a5f6c9d09c25de7ad81b3927ff087d8': {'title': [2], 'abstract': []},
#  '122850e39648bb4e46d0c8bf3462ae6d96a98493': {'title': [], 'abstract': [70]},
#  '405979966f6fe4e2e109657c9622675b2b43132c': {'title': [], 'abstract': [45]},
#  'c5e7e10f20cdd0979cf8a473ce9a6379786c7308': {'title': [], 'abstract': [96]},
#  '3b70789b0f6b870d79b106cba4662a20345713fb': {'title': [], 'abstract': [63]},
#  'b5b7757491d8f60eb68e9b5f64190443cdcf55f8': {'title': [],
#   'abstract': [86, 122, 124]},
#  'd7303dd15189c2a62a5564a1587a2eb3cc5a944e': {'title': [], 'abstract': [132]},
#  '6e18cc1cda44fb83cbbded9134f9015466a1c667': {'title': [3], 'abstract': []},
#  'f14c496d41ef5c46fce8380e99ca74a4639177ff': {'title': [],
#   'abstract': [60, 109]},
#  'bbb4788fbcf6603d65d636f25175d4478c46d806': {'title': [17], 'abstract': []},
#  '22f00826f391d564e1efcbd4809b4008393cea0e': {'title': [10], 'abstract': []},
#  '04f8b600223845364246c0c7e9bcaba4b0b7e8e2': {'title': [], 'abstract': [96]},
#  '491f7399da3c342c08da0b9fc54514f9667fe776': {'title': [],
#   'abstract': [41, 93, 105, 138]},
#  'a1de21ce6dd0ff6327e6cf5f124cce8db197991f': {'title': [0], 'abstract': [80]},
#  'd79653402bc292295774884525b129be12d79b79': {'title': [], 'abstract': [44]},
#  '95428bc0a3e657979be8b3dc559ee6139c22c0fb': {'title': [], 'abstract': [117]},
#  '04507020e4e003042150dcc8602505d1bec71c49': {'title': [2], 'abstract': []},
#  'f6a80bfb5fb23fdd940f1bf36ada123248346ade': {'title': [],
#   'abstract': [55, 94, 120]},
#  'c589c75e5afc2e08e749837ca2454bec80cfa76d': {'title': [], 'abstract': [45]},
#  '0f2b33fa678105e9b4aee3a22ec5c996af6e8460': {'title': [], 'abstract': [123]},
#  'baa6d79f0988369c77d6745b6026ee09600f1f11': {'title': [0], 'abstract': [119]},
#  'b9e98f630e8eaf77ddcd0f80d1360b611ae61e70': {'title': [3],
#   'abstract': [117, 140]},
#  '0ab9f556081db1845e883d53f11a3bff4d78315e': {'title': [7], 'abstract': [26]},
#  '29103b868a099324d857ad85ab3c6953c5bb0960': {'title': [4], 'abstract': []},
#  '1b0cbf49580883157dc2e674e64270b16656aed3': {'title': [], 'abstract': [92]},
#  '49fd588268a7a31838f5023fc174d7dadba71a75': {'title': [], 'abstract': [28]},
#  'bd25bbec1c321ab28846b04ee6d269e10e18f54b': {'title': [], 'abstract': [100]},
#  '21e9478db0dd7da17f595e42f457e42a34788f8a': {'title': [8], 'abstract': []},
#  'c987c7a4156ef65c1585925b62bcca7095376100': {'title': [3], 'abstract': []},
#  '9683066e554ffec9bec0c8a0c17bd07532f3b983': {'title': [], 'abstract': [119]},
#  'b98e47754b788d5421da5ea053a62fa53b760454': {'title': [], 'abstract': [297]},
#  'b32d295cbd3871e777ed7ad98b025e6ec3de521f': {'title': [],
#   'abstract': [130, 253]},
#  '4493fee3811f9a2853fb20810c09a90feb5a9b1a': {'title': [5], 'abstract': [46]},
#  '612b00d136eb6dfa568bbfea2b5149a760e8c68a': {'title': [4],
#   'abstract': [9, 50]},
#  '214c7052a5015e1f458d0f3ed8b8c9bf8a9b75bd': {'title': [], 'abstract': [68]},
#  'aefe73230387331ede939d38f1845adf0bc2e1e7': {'title': [], 'abstract': [17]},
#  'f7b1252bc6e64492118b262108003c690b6fc70f': {'title': [12],
#   'abstract': [31, 51]},
#  'bc35124d4fa7c9af515214cf1f94de70619bdca5': {'title': [1], 'abstract': []},
#  'c1c9b280fd657351d6718e4a0194b41c85832002': {'title': [], 'abstract': [24]},
#  '1de26d9d0418fd10e373883877b7c7dc53984b72': {'title': [], 'abstract': [32]},
#  '210e24e9efc2ddfba6131b33880e044e662255a6': {'title': [], 'abstract': [50]},
#  '9f244ccb395154fcdad3834d9e34d0a3be0d1a72': {'title': [1], 'abstract': []},
#  '5e159c0f1f56ebc51e8d44c18cf579a891ef1c5f': {'title': [],
#   'abstract': [3, 27, 48]},
#  'a623b38104dd06f601860632d6157ba17cc4d8b7': {'title': [], 'abstract': [98]},
#  '3f3df364e6b295dbac88e35e1e7bc2f3f4e5257a': {'title': [3], 'abstract': [41]},
#  '821bad7fa639314e35be00fb418ad926ad467983': {'title': [], 'abstract': [20]},
#  'c02da7ab4476983b27d3f7b34b6075be47856176': {'title': [], 'abstract': [151]},
#  '50240f45bbfadc58b7a1af55f16cf39a0b87f75a': {'title': [],
#   'abstract': [14, 28]},
#  'a22fdbc38c28904a3d0ed2f4acba597727d350d0': {'title': [6], 'abstract': [11]},
#  '310ebace48d022393727b5d0543d7429ff62e203': {'title': [], 'abstract': [91]},
#  'df5a33dbf12a6fe78b235782c977b0905eb97e22': {'title': [], 'abstract': [189]},
#  '122e8375dd47ca20a0aa29e3f987d82458a31456': {'title': [], 'abstract': [108]},
#  '2b461250c014b460e7c97b6138a3ee811f198f43': {'title': [],
#   'abstract': [87, 105, 132, 248, 383, 385, 620, 659]},
#  '0330c2a669bfb678ba2a79934c9c4cdad962105c': {'title': [],
#   'abstract': [57, 110, 116, 124]},
#  '02d4476f55b115e730a51828cac6397ba221b34a': {'title': [],
#   'abstract': [89, 99, 125]},
#  '6c86d3a9c66ebc5112f6e1a3534f2070a834de5f': {'title': [], 'abstract': [141]},
#  '4dd21b043326e305638f07fca3cd70de1cd1bcb7': {'title': [], 'abstract': [115]},
#  '678cddb453e8b03c738271a520ca0806f4fa7ca9': {'title': [7], 'abstract': []},
#  'f714356fe0fba7d5aca8734d3d2bac306c63936d': {'title': [], 'abstract': [50]},
#  '2d39dd4475857a54fd76600b164f68971b52bc8a': {'title': [],
#   'abstract': [3, 25]},
#  'a3db10fcab1692df72aae5d55ad88b15d2e14639': {'title': [], 'abstract': [70]},
#  'e73d0d9be6aefd9e509779b89ee455564f80cb3e': {'title': [], 'abstract': [3]},
#  '1572d6f602a3e6759d157bbd2b160eb00d1acb48': {'title': [2], 'abstract': [1]},
#  '2c88c3d8bc68858e4c9ba58ec3d71454e94eb96e': {'title': [0], 'abstract': []},
#  '042225e9eb60dc02407af9a1ab64dc2a30c1dccc': {'title': [3], 'abstract': []},
#  'de482cf043bb6fd70798f66ae1d3bdaf0ec5ce25': {'title': [],
#   'abstract': [30, 160]},
#  '702943c9ebeeb99234bc391e0876a8dcff1c0662': {'title': [], 'abstract': [62]},
#  'a90ea7dd27b53e35a2e73cf5589726f9b32611b5': {'title': [],
#   'abstract': [79, 115]},
#  'e43e4d57eb87089456f330dcd84202779da513a0': {'title': [4], 'abstract': []},
#  '0e9789615e4f3a55d300b8ca46070efab8a93513': {'title': [],
#   'abstract': [20, 30, 82]},
#  'f584aff2339e81b9f9553aee11aa12e35c8fc530': {'title': [],
#   'abstract': [69, 128, 143]},
#  '0bc65a52f245c1fdf462ba2850d59604ead44e15': {'title': [], 'abstract': [12]},
#  '61a20462dd8470cc5779b1ee929768151692818d': {'title': [], 'abstract': [90]},
#  '917dd30b5fbc8a26fe7922a17d1e1b1fe2d30494': {'title': [4], 'abstract': []},
#  '0872dfacadb282200f909e167e34dd9a7d9f27cd': {'title': [],
#   'abstract': [48, 63]},
#  '51ba3b33f445199d9f3cddb5b00c7e2927199b0c': {'title': [], 'abstract': [87]},
#  'db6f5ac301be9f996330c9e5d96e2333bcdf54a9': {'title': [],
#   'abstract': [36, 58]},
#  'f1b131c46aff6fedc815c2b2f3fc5680e22ddb6b': {'title': [], 'abstract': [65]},
#  '911b065cb560a68eb16ce28be298a1e1392faeac': {'title': [],
#   'abstract': [107, 119]},
#  '43cd09d920b4826fc34db7ad79a7eb6b1f2b394d': {'title': [], 'abstract': [158]},
#  'd2394298565733afe3242d577b5686d1b1607044': {'title': [], 'abstract': [95]},
#  '9282b976581d8fa0b7926fc55982863927978479': {'title': [],
#   'abstract': [23, 45, 114, 256]},
#  'c1299bf2cbe5cf743340c408687d4de55dae809a': {'title': [], 'abstract': [97]},
#  '4de411661760ce52e5fff82d4a0c5b84f82ae0bc': {'title': [1], 'abstract': []},
#  '4a3510f8ea66abda5627882d51ca15ca99b9ad5d': {'title': [],
#   'abstract': [32, 51, 91]},
#  '47d23cead3606d95f206af14d6a5fc6c29862eba': {'title': [12], 'abstract': []},
#  '47af313d4887c346ec12c7c69e876d57ff3ae9a9': {'title': [3], 'abstract': []},
#  'aea3867b305fb22959ba741526495480e003ae43': {'title': [1], 'abstract': []},
#  '2996532389f9e6e0231282a71184cacb91fac36c': {'title': [], 'abstract': [79]},
#  '59d4fb614f9330b5b9b0a9957cac51faf8e058f0': {'title': [],
#   'abstract': [60, 98, 110, 121]},
#  '61eddc08e5e9434ff53a0b7d6465da2c96e8fb12': {'title': [], 'abstract': [32]},
#  'e2411f99a5c42cf7498393b3b2177d721ed8f5f1': {'title': [], 'abstract': [129]},
#  '9b9ffd35ecf3491c3aaca4c583d9e1f39a67bc95': {'title': [], 'abstract': [76]},
#  '928b7b3d66b5cde3c40f288585225cf10273f6bd': {'title': [2], 'abstract': []},
#  'cd942a49428153982ddaf95b5daf05833e893a65': {'title': [], 'abstract': [29]},
#  '83d1db498846485904d3281ba5bed7edf0f1b97a': {'title': [], 'abstract': [55]},
#  '5b0727d37f4da1bdba09db6e94aad65eca23e595': {'title': [], 'abstract': [18]},
#  '20c7dd3690a71251d64721039986032c7507b98e': {'title': [], 'abstract': [17]},
#  '38cf8d61e98d6263cf05a78a0f0712f56c802c46': {'title': [], 'abstract': [72]},
#  '3ad083dd2fccac3a3b75bd5e7c8886b19c7c6221': {'title': [], 'abstract': [29]},
#  'fb4bc8155d47603b81d7e91eff438cb30e8835ac': {'title': [], 'abstract': [45]},
#  'e67c37f6aeb507d6bce158bbb6f83e84a680d80b': {'title': [], 'abstract': [54]},
#  '380ebe7b838140ae5d5486d1d2dd909a36dd866e': {'title': [], 'abstract': [75]},
#  '34f1362cb524277528b9d0527f528e33510ef01a': {'title': [4],
#   'abstract': [1, 58, 70, 119, 134]},
#  '4fa4fe9b4359baf41b92a80130d9ddb4dc4ab1a2': {'title': [], 'abstract': [108]},
#  '767557b5d54467fd6051db172cdb729d2cfd8932': {'title': [9],
#   'abstract': [3, 50, 78]},
#  'f52eb754dcc0709d63fef3272b17fc102c801a47': {'title': [], 'abstract': [56]},
#  '5fc0e963563faec304020b206e057cd75f3c7547': {'title': [4], 'abstract': [29]},
#  '03f643f4848e28b9c344b8bd95d28690ee35b128': {'title': [],
#   'abstract': [41, 92, 139]},
#  'c568e9cf107ada6d1ccb634d79d7602b449c5ee0': {'title': [], 'abstract': [28]},
#  '66dde2d43ec0e3cf7370a53773953c17c9b312fa': {'title': [], 'abstract': [59]},
#  '967269d13e99821dcf6406d093c7a2db04634547': {'title': [], 'abstract': [60]},
#  '8835dfcd05b38ba5129df48e0948249cf518152e': {'title': [],
#   'abstract': [28, 114, 124]},
#  '428489d732a80b9b2dc77d1780b316b355b025f0': {'title': [],
#   'abstract': [144, 185]},
#  'f124226320f71a476256795e766d9137d00a522e': {'title': [], 'abstract': [11]},
#  'cf65597c6e366f5c8d9fb86f76929a04519968b7': {'title': [],
#   'abstract': [89, 126]},
#  '8fa6530101d948a129be95cb9c0ca64ab4588a50': {'title': [], 'abstract': [118]},
#  '399f524be265b524336576658a3cce34324adbd4': {'title': [], 'abstract': [65]},
#  '6305fbefaab76652f263d7586a3c801b249dd360': {'title': [], 'abstract': [84]},
#  'b9046042830f6906c2db1d6c31cc1f8c10348fc0': {'title': [], 'abstract': [102]},
#  'ac8a4b9330b9cb279c86b35e1e718110533fc30a': {'title': [], 'abstract': [74]},
#  'a6f5c8d82f27bd68eb4cc40bc3d0b00fccc5d469': {'title': [], 'abstract': [111]},
#  '2c25097f1c59de21d65c656911393412d3227a16': {'title': [],
#   'abstract': [84, 214, 224]},
#  '111d8cf1dd5061e470356657db33317491c3094d': {'title': [19], 'abstract': []},
#  '9de1ca2678f4d49713dbd5303a6a89d9615f2e5d': {'title': [], 'abstract': [83]},
#  'd4d2d4e033f893f25d1a93f6b126da6658cc282b': {'title': [8], 'abstract': []},
#  '58f842afbc5944371fddc412ee8cd67451199abb': {'title': [],
#   'abstract': [70, 75]},
#  '14752c8b3b9373c469c95f842ad3f4fca95b0997': {'title': [1],
#   'abstract': [148, 201, 221]},
#  '952b30aae0ebc4ce9f3b5eb169d82873ca448f80': {'title': [], 'abstract': [69]},
#  '5fd28b66698a27deba48e8b98e756a1dd00001a0': {'title': [], 'abstract': [87]},
#  '8cb088ef78da717836a7334c61a5bb592b97d464': {'title': [9],
#   'abstract': [39, 88, 120]},
#  '2b4888e6ad68ec270cad76008745f9f9580e30a8': {'title': [3],
#   'abstract': [33, 60, 89, 93, 96]},
#  'd94c729215059857d19da3a6b0a297e1d863843c': {'title': [2], 'abstract': []},
#  'c69c3f82c08b09e7c45cedcac71cc3391aeb668c': {'title': [],
#   'abstract': [2, 41, 82, 220]},
#  '2d8e2f522daed51e211838ac0e2ee8538c2d280c': {'title': [], 'abstract': [29]},
#  'ce3825e6620cbeeb1e8c6941b82dd4c35284d482': {'title': [], 'abstract': [196]},
#  '35f21f6870f2d40408aa084d1c7902d34b06bb86': {'title': [], 'abstract': [112]},
#  '29df91ab84ec11f56fb44620b465bdf5a7a473a5': {'title': [], 'abstract': [159]},
#  '1a08532c2a48986afd4adfe7a04c1d81e49685b3': {'title': [], 'abstract': [31]},
#  '4e199001c7c152754043b639745d8f462c73456e': {'title': [], 'abstract': [97]},
#  '71c6b01eeda3603b3af6eaa74e057f1b7a1ef792': {'title': [4],
#   'abstract': [33, 45, 80, 193, 292]},
#  'bbf052271c70dd926cd230bb5640cdcdfeccf1cc': {'title': [1], 'abstract': [63]},
#  'f2a32635c85aa87cbab6d696f40cbce2c4143cf2': {'title': [], 'abstract': [142]},
#  '74ec403743704c1d72b83c96d422996bcf232b1f': {'title': [4], 'abstract': [71]},
#  '60170ca51af9dda002b6b4ee2e14106401fb8081': {'title': [],
#   'abstract': [52, 91, 93, 142]},
#  'a054752d1a3878b44cf5275f56ea90dbda85f00c': {'title': [], 'abstract': [130]},
#  '08d0ea90b53aba0008d25811268fe46562cfb38c': {'title': [1], 'abstract': []},
#  '5b85c515a79ddb7aa60f82a0f9102027dec65277': {'title': [], 'abstract': [109]},
#  'de5a83eeccaa4b69f5c6a89a3f2a573f1e9a8bee': {'title': [],
#   'abstract': [121, 152, 162]},
#  '76e9c4765904d5c3b93fb90b8b4730f7b8a0830b': {'title': [],
#   'abstract': [86, 88]},
#  '978289c7431e900738e3dd4a868d199c89e074ba': {'title': [4], 'abstract': []},
#  'f3b663dd79d93768aec8970780166b9c872562a0': {'title': [4],
#   'abstract': [50, 94, 97, 192, 200, 205, 211]},
#  'ea255a83450518a7e1a064ebed714eced5d2a86c': {'title': [],
#   'abstract': [24, 68, 78, 98, 110]},
#  '5bf5b98677af188ec763821ac35086810d86b5b0': {'title': [], 'abstract': [33]},
#  '8711cea9e4af17b73427b55dc62fabaa7e576d88': {'title': [], 'abstract': [105]},
#  '2ca8f2bc9935e80e06fff6d0e07fa9980b965007': {'title': [], 'abstract': [37]},
#  'a84632b33324c1330c007f2c5c1764704b3ee510': {'title': [1],
#   'abstract': [47, 57]},
#  '36e2f487ea2ec46b9030548e0c80b592c122306f': {'title': [1], 'abstract': []},
#  'd9a9667b714ccf8ec99a227ebee9dba029116545': {'title': [],
#   'abstract': [24, 164]},
#  '4d4f873640edfa076a8db0195d386b0c8439255e': {'title': [], 'abstract': [24]},
#  '4f8bf7de1d0632ebc5e9d5a1da14c63ad3b7124f': {'title': [], 'abstract': [125]},
#  '5bdb19eafb8ab460ba5be4fa90cde915bc338786': {'title': [], 'abstract': [24]},
#  '048e277bb208445e7a5e4b29ece99a60e1331d86': {'title': [],
#   'abstract': [74, 96]},
#  'db0a2539b8e1874ec50638be0b37db0dc33c8c22': {'title': [],
#   'abstract': [69, 76, 94]},
#  '3832b3f266c10eb3b9f41e8dd8f6b467718b8c08': {'title': [], 'abstract': [2]},
#  '5d68bbeb2d293cbda75994ca5040fd083665e82e': {'title': [], 'abstract': [83]},
#  'd5268374c5a2c5ac073086358340f86608239909': {'title': [], 'abstract': [103]},
#  'f4e0c2fd49adfd999fa32e11f64c574277230d51': {'title': [1], 'abstract': []},
#  '7d98d1dbf7bc913c6aae07c481fc9dd05f3b3964': {'title': [1], 'abstract': []},
#  '5f58c4eef5728d53d124de6226c134d2e28d846c': {'title': [], 'abstract': [82]},
#  '231959a0267ac06616a101efe6aa290df555f4c3': {'title': [],
#   'abstract': [125, 176]},
#  '5d86691f71db87c7fc790fc3ed661fb858454dc0': {'title': [], 'abstract': [70]},
#  'b2d6a999fc0c055b81d142933a517f64040bfda6': {'title': [7], 'abstract': []},
#  '6c6af35fb22f395e2219b7cc71bc2552bc48d20c': {'title': [], 'abstract': [38]},
#  '1feb658d12538a2b12bdf3227bf6d6a9476fa51b': {'title': [], 'abstract': [86]},
#  'f62255f06182a39e970e5e64014f9f61065bc467': {'title': [0],
#   'abstract': [38, 74]},
#  'd939289250e4c635ae2d3e80834862d392473100': {'title': [], 'abstract': [135]},
#  '8a745e26217d302a74ea8a6aa0025fb7fe84b5c4': {'title': [],
#   'abstract': [28, 58]},
#  'b950bb5eb34af83893df328eb2dbf4d6c966b39e': {'title': [2], 'abstract': [38]},
#  '3efa96570a10fecba0f93e0f62e95d41ce7b624b': {'title': [], 'abstract': [38]},
#  '20f77d34ab1aec7d0a6e613a740aff7ec7fbf55a': {'title': [10], 'abstract': [7]},
#  '2307f9198910e26744ff76aa7649d9e7ca849352': {'title': [], 'abstract': [61]},
#  '05e9e85b5137016c93d042170e82f77bb551a108': {'title': [], 'abstract': [88]},
#  'e38e70580acb204c05096de8da90b7ab1d4bdb6b': {'title': [], 'abstract': [87]},
#  'a12d12c3f60ec47922e6d6dde63f87e7ee95f689': {'title': [7],
#   'abstract': [110, 141, 260]},
#  'a062db645dc6d7e597b35eddc65045e66f256599': {'title': [],
#   'abstract': [2, 16]},
#  'eda708c23ad0024b25d48d9b5f9d5483f29d99c4': {'title': [9], 'abstract': [36]},
#  'd75de30c90ae8cd3326175f82d77add28ccc53fe': {'title': [4], 'abstract': []},
#  'ac4f0fc88fa92a3f33109b4c2bc23339565a4e9a': {'title': [], 'abstract': [62]},
#  '197906e7eb46f3b98757acaef60d3369158e17fa': {'title': [], 'abstract': [81]},
#  '03a0af422dc750f2629244839862df8ed28b83d5': {'title': [], 'abstract': [132]},
#  '72dee07928ce8e98760598beeb97a373ad424588': {'title': [], 'abstract': [63]},
#  'c1b36bad6d2e73d41bf0cfc50ea504c5187615fe': {'title': [2],
#   'abstract': [31, 73, 136]},
#  '0dd22976ac03d2ca2f83f00abf5e44c9154d5cc9': {'title': [], 'abstract': [58]},
#  'ea19872ecc3e8e4768ce922544ad775cffd79855': {'title': [],
#   'abstract': [19, 143]},
#  '9702b3da2cca9b9f9ca53c0be1de09b644a9e34f': {'title': [], 'abstract': [19]},
#  'd3caa44bd07c08fb8c0c36f68a4cb0bc171ce3d6': {'title': [],
#   'abstract': [11, 78, 103]},
#  '2a3f8208aadb36d1c90d869252fa5f052bace572': {'title': [2], 'abstract': []},
#  'c308ece8b548342f2eac8dfca1f63004ab2b62f4': {'title': [], 'abstract': [19]},
#  'df7106a7bca446efe8bc37062f0442e7b9aedfa4': {'title': [],
#   'abstract': [32, 49]},
#  '3a9038c56a4fdfca11b5dfde98bda1dbd87aae57': {'title': [], 'abstract': [2]},
#  'e0a950ed50128949cd507645064ffafdca09ab69': {'title': [], 'abstract': [45]},
#  '09730e5203201cc45c431e010307421b33bb0f8c': {'title': [], 'abstract': [64]},
#  'e6b93ba6e6f38f1a6812ef2245523ef5aeb63fa8': {'title': [], 'abstract': [136]},
#  '4ea6c55153516d82e27da275ad088b0f7c685c9c': {'title': [], 'abstract': [35]},
#  'a2004b751456232769074db004a60a8a58dd6ee9': {'title': [], 'abstract': [39]},
#  '74e6dfc915e9b353422084f30f50a6f6a3bbc3af': {'title': [3], 'abstract': []},
#  'b38eeec1c63fed013262fe34286042d11bb96609': {'title': [], 'abstract': [2]},
#  'ba7ec7c5023735c7ad01e04c0b1a860a24a452a0': {'title': [],
#   'abstract': [65, 90]},
#  'a0760f5138048d6721f0852b0cc445056ea3251a': {'title': [2],
#   'abstract': [0, 24, 32]},
#  '602645d132457923c98794db8f6d4a042714620e': {'title': [],
#   'abstract': [8, 130]},
#  'cdbc83c851f9ac619971f2bb0919d3097f73e07a': {'title': [11], 'abstract': []},
#  '7e1b5de9e0a8767a3d4071ea1299358dc067f7e3': {'title': [],
#   'abstract': [91, 100, 110]},
#  '5ef02a9408d86cfba7aa362cd66f80c585fee17f': {'title': [5], 'abstract': []},
#  '2c234b9f8071e0b2c516489ffebf22822abc3845': {'title': [], 'abstract': [95]},
#  'a1b061246a67299b82ed37c50a5f4e4c7a4eae80': {'title': [], 'abstract': [38]},
#  '7de2877a9a0c20379bf8d843a829547266dc556c': {'title': [],
#   'abstract': [73, 218]},
#  '6ec2d2fa03da679f3a52f3e5cb9013d3fb5c06f6': {'title': [], 'abstract': [49]},
#  '5cc578a08165a656520557d42c7ddd38fc434bd1': {'title': [], 'abstract': [30]},
#  '27d05623e09bd55ffd46eb846010b2549d98f704': {'title': [],
#   'abstract': [34, 44, 71, 92, 101]},
#  '7aa5e295db536dc0f2fe781d75fa2148236a0d2c': {'title': [], 'abstract': [50]},
#  'b5fe1c52bc9f048a48d96a075a3ec0059a6cd14d': {'title': [7], 'abstract': []},
#  '6bda343f504e47b1fce4b1f09ccf1281bc65c23e': {'title': [], 'abstract': [130]},
#  '90938eb37bec7dc7ffe5fa5c6160883f8d079255': {'title': [], 'abstract': [117]},
#  '56c6cc360cc60f20884851daa8943d16219fb5c2': {'title': [], 'abstract': [0]},
#  '0661678ca7a4348a9e2fc5b1a39b0e4a8a4aa6dd': {'title': [5], 'abstract': []},
#  '37b1f7054f81764bb6e540fabe1d1a17717a4291': {'title': [],
#   'abstract': [105, 143]},
#  '8ec4d8d0d7b82d9b02393b05cf4fe8613c2fb46e': {'title': [], 'abstract': [81]},
#  'c89593ce12703b21266ee669649f113144ad7a38': {'title': [3], 'abstract': []},
#  '5efe15ac1bd81a9d80746e0f0325b15854222353': {'title': [], 'abstract': [94]},
#  'b4e2f6fb0b3de2f6c8d44ce0d2c6cbae63fe64f9': {'title': [],
#   'abstract': [18, 151]},
#  'a488586598ac9dc62e03653ab1dd85c55932f29d': {'title': [5], 'abstract': []},
#  'b381f4b3edfb28646986b78ad894fda7f56ffd53': {'title': [1], 'abstract': []},
#  '8a9dbbf2d3c3c214eb28116802f2983517ec56e8': {'title': [], 'abstract': [9]},
#  '0fa6b579792b5e21c60942ab2152f1d0205bb1dd': {'title': [],
#   'abstract': [116, 135]},
#  '1e747c51d4b8ec244387eb4cd0053acab9fe8084': {'title': [8], 'abstract': []},
#  '33089492172b652f443ad9cd39f796e233622111': {'title': [1], 'abstract': []},
#  'c4e0f697842012f753e8760202acff1b1245094d': {'title': [], 'abstract': [146]},
#  '74039f9830fa5171ecf879edbcdce9791c1be45f': {'title': [8], 'abstract': [13]},
#  '82060011c4e380f7ec35ab4686c6e8a83965b1a5': {'title': [2], 'abstract': [84]},
#  'eb2fd179b9728928f89e82e49605e1e331f7cf97': {'title': [], 'abstract': [88]},
#  'fd81880d09fa9997be8a0fccd5f1bf3fc4eb3fcb': {'title': [2], 'abstract': []},
# ...
#  'fe06873049eb201eb509b39c1a1e5e787a0466ab': {'title': [], 'abstract': [65]},
#  'e570432e0fbaf7e2f9d07ae2088161d4f9c61027': {'title': [], 'abstract': [87]},
#  '076f263a4f788df5b930146fbd5cf8193be7ad91': {'title': [],
#   'abstract': [74, 99, 118]},
#  '4c4c47b928be4dbc5140c5bca2f7e75e5f432a5f': {'title': [], 'abstract': [1]},
#  '42a5578dfc2bf878439b3171fedd4aacc9e81b86': {'title': [4], 'abstract': []},
#  'f9d2a79a5e96e7f13445fd736a4f69f81bef5aed': {'title': [3],
#   'abstract': [1, 64, 153]},
#  'ce080083a7a3d3177732dff0da508e0da152837d': {'title': [1], 'abstract': []},
#  '36145fd6281884a8e59ec3cc8d76c22fcb388628': {'title': [1], 'abstract': []},
#  'c54c5b283138525128c53dc761616d0a32452318': {'title': [2], 'abstract': []},
#  '42bd55fa0b4a3c0596f5f9a1d2224b4e0329d69f': {'title': [5], 'abstract': []},
#  '790175cd1cdccde6666a4e08dbffae0782dfd9eb': {'title': [], 'abstract': [84]},
#  'e1254ed57900289cdcbfce4d0ef01ff10a582f7f': {'title': [], 'abstract': [32]},
#  '419b0234c7e32567131f325c0c0d73adde808ff8': {'title': [4],
#   'abstract': [5, 47]},
#  '0f958468b266f0a73561237593a82ded729d63d0': {'title': [], 'abstract': [44]},
#  'a39d00870b3ef5d8221411af7683c85111a9165b': {'title': [], 'abstract': [84]},
#  '4a06c596ac9e23b1029f17d564af939d422b8b25': {'title': [], 'abstract': [83]},
#  'd735ed23232882d72974787d2ff188c40232b360': {'title': [3],
#   'abstract': [21, 30, 57, 67]},
#  'a4ea36b03e0117c6d2851154e4205bfe4fbb0749': {'title': [],
#   'abstract': [74, 81, 112]},
#  'd66772a16f5f3932ab1aa08b637d3b0422675afc': {'title': [0], 'abstract': []},
#  'a0e1b65c7bffc0a909e7ca225e48afe5736ec3bd': {'title': [],
#   'abstract': [99, 142]},
#  'f467146811515d5a32460275406cb27dee243934': {'title': [5],
#   'abstract': [476, 503]},
#  'eb57daa339f87f00c273bbeb8efd7dd2a1c61ed5': {'title': [], 'abstract': [35]},
#  'f187860ec47bf83b46f78f8922a10a323cfaa2de': {'title': [6],
#   'abstract': [108, 116, 145]},
#  'b617b85b5add24d55bdbd952cb5bde52b01e4869': {'title': [1], 'abstract': []},
#  'ad6f00dc68564a369998a099bc7f1e9a9be4b13e': {'title': [], 'abstract': [71]},
#  'e0c6abdbdecf04ffac65c440da77fb9d66bb474c': {'title': [], 'abstract': [90]},
#  '52f4ff4b93e5be152842180d950a24ea83dcfe5b': {'title': [], 'abstract': [79]},
#  'a3cbabdfb2e0ca39b77ad33b665ec2becc6937f6': {'title': [4], 'abstract': [152]},
#  '338cca879f2a31749d945943333459cd2187315d': {'title': [], 'abstract': [17]},
#  'a8ae2d8232db04d88cf622e5fabd11da3163aa8f': {'title': [], 'abstract': [67]},
#  '0b86c69d42bbb882f2d83358c73dc548477bb92b': {'title': [11],
#   'abstract': [50, 68, 82]},
#  '3e527a1f4a52b6b744d1f1ab692b86e269bcbb1b': {'title': [7], 'abstract': []},
#  '9cc8609f904c50b1be408abede7ab7f5cdbc9744': {'title': [], 'abstract': [94]},
#  '2d0fe77c1fa5e814122478f5a3ef2ad018502120': {'title': [], 'abstract': [44]},
#  '9b1e4e897b62085f2f4d731e5c3ec891b76b76cd': {'title': [], 'abstract': [89]},
#  '8541bc2b3e97861787715191e5872d6a96784a52': {'title': [], 'abstract': [36]},
#  '3f77d2d9bfdb8c39dd4cfdeff1f5482abea3e6c6': {'title': [],
#   'abstract': [57, 62, 94, 107, 114, 129]},
#  '7473744a01c896aab2839658b8cf3bc328f91fc2': {'title': [6],
#   'abstract': [127, 139]},
#  '919e0132062b7d4d9b05f557df2ca4c7be13d4f5': {'title': [],
#   'abstract': [5, 14, 19, 72]},
#  'bfe877a2f1049775884e39eed7b1a1b651ddffb2': {'title': [3], 'abstract': []},
#  '0ae597c29ec4c91916c892313c093c9895bb1212': {'title': [], 'abstract': [65]},
#  '301796c7b0789560401e25d3459284221e314886': {'title': [], 'abstract': [93]},
#  '046371ad4fd23f46adac98c01000f050004cf0cd': {'title': [],
#   'abstract': [13, 27, 38]},
#  'bdaa483118aca85811f4612b78122d33d611129e': {'title': [], 'abstract': [73]},
#  '97d47609a78b68c80164b2e776948424112aadff': {'title': [1], 'abstract': []},
#  '1dc088e1ca5538aff0c9912ec63ebba0c961748c': {'title': [], 'abstract': [80]},
#  '0ef2fc480b5532e1a5fd94b046e85f3276d4d860': {'title': [], 'abstract': [106]},
#  'b3c602ed5232ae3d99ffa0e9c4c213cf726e67ec': {'title': [],
#   'abstract': [52, 158]},
#  'b6206496946973bdadac5b39de2bf019bbbfcc8b': {'title': [3], 'abstract': []},
#  '431d8c2da394a07795cd1bab5dc36fc82c7275d3': {'title': [],
#   'abstract': [4, 69]},
#  '33ab9fda1b364c3958a7ac43ae02e15b028f1bb2': {'title': [], 'abstract': [12]},
#  'c31ec171a68dfdea5556e1865411f6c587d4bacc': {'title': [10],
#   'abstract': [29, 60]},
#  '9e28d37b5732c5e20abf822b9d098a0a41aeac06': {'title': [3], 'abstract': []},
#  '9ca53fbbe0287e4795f35e55819f4c03b405c3af': {'title': [], 'abstract': [79]},
#  '49bdeb07b045dd77f0bfe2b44436608770235a23': {'title': [], 'abstract': [38]},
#  '26ffc0f2e132de0f683a5dd48154559cdfa82b0a': {'title': [11], 'abstract': []},
#  'd56c9979027122544a5b5c7e2708304b900974f9': {'title': [],
#   'abstract': [58, 116, 179]},
#  'efd643a0aec2dcb7952550f64f3283e26517ae3d': {'title': [], 'abstract': [56]},
#  'c9d843d4f2b7a5ec37189265de2b933039bfc878': {'title': [], 'abstract': [18]},
#  '632841ebaf485cd55e225ce8fb7e03fae6dedd3a': {'title': [],
#   'abstract': [56, 82]},
#  'd90e5875fb46b69aff259c1b6b8c6bd83f7dd06e': {'title': [3], 'abstract': []},
#  '6f8914f0d5bc5ea576d019c11ad9e0ab78619368': {'title': [8], 'abstract': []},
#  '17eb3834afebb8100a5b07467e73c38cd4baff48': {'title': [], 'abstract': [19]},
#  '890ca196ba7aa6ded82538c05321581398a18a21': {'title': [], 'abstract': [75]},
#  '35c0d6ac0be8ca7a554056be532dc6fd84cac415': {'title': [], 'abstract': [204]},
#  '01425c6fa007f52ce0ed351e3691c294357da114': {'title': [0], 'abstract': []},
#  '0daae690d05867591884532bb68d672b19643438': {'title': [],
#   'abstract': [29, 63, 104]},
#  '281e1000e0f9873f217a1d5895036ee72a54bf7a': {'title': [], 'abstract': [6]},
#  'da4e88fccfdfd1a33231c852c0c3afec5cbc2a34': {'title': [], 'abstract': [47]},
#  '90c584574af4681e9ec8830aad5f6524d6844148': {'title': [], 'abstract': [85]},
#  'd187411c981896108212066ae1cb55a17bfcf836': {'title': [], 'abstract': [124]},
#  '3984684346c39fd027f1c20b16cecc3ac744b266': {'title': [], 'abstract': [20]},
#  '5dac7604b899ff5c85a9ef0b16132243b7d99aa0': {'title': [0], 'abstract': []},
#  'fc52c657a46973ae5e6f558e004389c170cee377': {'title': [], 'abstract': [53]},
#  '0c555ef3e1d5dee7fd9c7a4e25da678710c4304d': {'title': [1], 'abstract': []},
#  '1b1a24b0d64fe5a74f12513111a644875f6f8c15': {'title': [], 'abstract': [3]},
#  'e1026f240d59a80493de8f55521aa32f1d9b04d1': {'title': [1],
#   'abstract': [1, 59, 62]},
#  '4c861094323ccfc2a5cc7d7fcf4943b053f87e10': {'title': [],
#   'abstract': [84, 138, 177, 192]},
#  'e0b92168fd136f2e5f3d3697ce9f73c94b04cd43': {'title': [], 'abstract': [145]},
#  '37595f7a51982d776e57c7280b9445474d90f0be': {'title': [], 'abstract': [122]},
#  '2e72687a7300945476500a96f256ef529c24fb59': {'title': [4],
#   'abstract': [68, 81, 130]},
#  '661c357c06f4176686180c6e534560229483b03a': {'title': [], 'abstract': [54]},
#  'b6926174a9726bfca09836b80aa715ae89a1a1b7': {'title': [], 'abstract': [89]},
#  '6c83fef3ac06cabcd459164fc94b0492e67606f3': {'title': [], 'abstract': [91]},
#  'e1e7f88511adf941d92daae6d5e3e18c738847d9': {'title': [], 'abstract': [105]},
#  '82b2f8cd8b50f91cc4a03d6524352b4187b6f72b': {'title': [4], 'abstract': []},
#  '5e6071ab97f115705864ebe2e8e3609f94641d9a': {'title': [], 'abstract': [71]},
#  '60b2b3eef7c4d9ac074a0256bc61db6fb36dd3d9': {'title': [], 'abstract': [18]},
#  'd88158745b69f5732397175389101e2d98799c00': {'title': [], 'abstract': [16]},
#  '0837c782cf3967cfb2fa7b59bca6c58ee9fde603': {'title': [], 'abstract': [1]},
#  '6f11daad0a6a1e5540e47047928152d11d7f05a3': {'title': [], 'abstract': [13]},
#  '2a2e1ff4a26f6013186b06fa5d9f63df9148022d': {'title': [],
#   'abstract': [66, 136]},
#  '36e6fcef548fc2aaf3f9ec5cbe1c498b942c65bf': {'title': [13], 'abstract': []},
#  '4800a612910e4daec6426082499dbfcc2f8ca5cd': {'title': [10],
#   'abstract': [25, 164]},
#  '2555427fdfecd6e5488e623b46e5d160e96cfe8e': {'title': [],
#   'abstract': [32, 74, 124]},
#  '4e9ac0f2da8c66d10d20994c4b15ae991c2069f7': {'title': [], 'abstract': [144]},
#  '7104e07d2e602a184c31bf72d95ddf48e507f0b5': {'title': [],
#   'abstract': [79, 94]},
#  'e4484b7500b63f7211623554959560c8c6f85981': {'title': [], 'abstract': [60]},
#  '6d427b230714e0b9d19b5dbe1d0d585c934a0306': {'title': [], 'abstract': [32]},
#  '0ca95a34c0a59132e7f0925b189de884e51a93a6': {'title': [], 'abstract': [161]},
#  'c3f89364aecd661eb032840d2fe3efd0f6d1698c': {'title': [], 'abstract': [83]},
#  'a9273889f2a54aacf19f62fb8b859eca8058b728': {'title': [], 'abstract': [35]},
#  'c3835fef0bddfa63f43d0aca20d3be86540af451': {'title': [], 'abstract': [89]},
#  '53f3f6042843c01b2425a11a0e32da12aa589b8f': {'title': [],
#   'abstract': [34, 49]},
#  'f708bbeeb914d00246955373dc8351a29b410eeb': {'title': [],
#   'abstract': [56, 71, 104]},
#  '1b2dc6dff97481b866df819fef4b9255806fe4a7': {'title': [9], 'abstract': []},
#  '032b412c1ddcd24a7454a4434043b030a366cf1b': {'title': [1],
#   'abstract': [14, 22]},
#  'a7329560eb66b7400e24d82a8549fe1f55285537': {'title': [],
#   'abstract': [65, 117, 120]},
#  '3c17f5cdaa67d293299b72f9fc2541eee784dc04': {'title': [],
#   'abstract': [85, 111]},
#  'e078ee00ad8e83a455e4b3f392179ea9b545099e': {'title': [],
#   'abstract': [15, 30, 79, 96]},
#  '698d1c1bdd2af07d81b90d68c1c758f9e4896841': {'title': [], 'abstract': [120]},
#  'ccf9076811d29545913e7dc03c36575d7cd8abb9': {'title': [], 'abstract': [76]},
#  '2eda7601414e01812a6beef7d09c72732d367610': {'title': [], 'abstract': [91]},
#  '24029683600238e055e309378ca33d6f2c1adefe': {'title': [],
#   'abstract': [36, 128]},
#  'f62894cfabc8a9617768da819ba95a6d2f527a46': {'title': [],
#   'abstract': [75, 112, 125, 132, 153]},
#  '9e749cb75bdba7ab0cfa8ea7d3d88d6673c14f8b': {'title': [], 'abstract': [102]},
#  '51dd328dd38df415c36b24119119790953b13121': {'title': [], 'abstract': [43]},
#  '7c7943c4398773aadcb590d6c27a8a2633344d69': {'title': [1], 'abstract': [121]},
#  '2fb824369b653cd4b9344f2143bfb54de3d7dd23': {'title': [5],
#   'abstract': [41, 50]},
#  'e6721913a709500ea5670104f71731570a37d332': {'title': [1], 'abstract': [2]},
#  'fb83bf6a98084deb3050d919e1a00ebdc2893a96': {'title': [],
#   'abstract': [39, 94]},
#  '7bfd24b2e5029b53a2289a5ff52cf9b2ebb187c5': {'title': [], 'abstract': [122]},
#  'f20f40a28f0e6a18f6008ef333d04a84e7ef32fd': {'title': [], 'abstract': [73]},
#  '4575e8d03861e2b8a445810053c61180d9e60c4e': {'title': [],
#   'abstract': [54, 132]},
#  'c8d83f7a38a5d4796b7ac4753e11cb10e1230a7b': {'title': [], 'abstract': [124]},
#  '36ee6757e8f1a8f53d7506190ad305fd3b67a9b6': {'title': [], 'abstract': [9]},
#  '09f7c0c22f635179ea8807c599009a02e5e108c7': {'title': [],
#   'abstract': [78, 104, 115]},
#  '747c6c2163fa3cdaa23e8fa48a8fd8bd1bed241a': {'title': [7], 'abstract': []},
#  '03816d71cba2103556e9877fa50eecc049ee740f': {'title': [], 'abstract': [27]},
#  '09ddee7b5c2c0c49c190c401d6be25c757b696fd': {'title': [], 'abstract': [50]},
#  '5db166a07c850bffeacb5dc41347c2c21cef4e5f': {'title': [],
#   'abstract': [51, 104, 108, 118, 129, 210]},
#  'c2b0b6cc71d26c3e0faebcfee953c1eb00697001': {'title': [], 'abstract': [130]},
#  'a97fc03dd0a67641e51617ac9f722bdae82993a4': {'title': [18], 'abstract': []},
#  '01999ffcc0f8ca6e113fafd17ec8da65d2b9a18a': {'title': [],
#   'abstract': [82, 116, 132]},
#  'e05799a258c74ba13bbcade805de5baa7741b502': {'title': [], 'abstract': [118]},
#  'e8aea45fe14f425c4ac1c5e0c95c5d0f92a2c317': {'title': [], 'abstract': [52]},
#  'f55c5bcd83746ad9a97f5a957790a35f672465d6': {'title': [], 'abstract': [91]},
#  '4dac3008a75cc55ee21460dcabeebf330ac36e79': {'title': [], 'abstract': [15]},
#  'b444ec32f27b10bd16627a7d5db6040916a8a724': {'title': [], 'abstract': [53]},
#  '9d5f5a102e8e59ed1f49c534f5bd8d9cabc013b5': {'title': [],
#   'abstract': [101, 124]},
#  '71932fab072bd5d3166a100e061c5da23749ad76': {'title': [2],
#   'abstract': [6, 42]},
#  '40f9533afdf4369bc158fd98b1e72739e2fe7426': {'title': [11], 'abstract': []},
#  'c84d16132bd56f047b4bd3ab23dec711a692c0d3': {'title': [1], 'abstract': []},
#  'c8b94734801ac1a8141d0125893fd3170dcc8d6a': {'title': [2],
#   'abstract': [88, 216]},
#  'de51d9de79c41bdac948c4a2a88a7e372535451f': {'title': [5],
#   'abstract': [127, 233, 261]},
#  '0299fb306366c8f72dc4c8e38cb111755b5a4f70': {'title': [], 'abstract': [115]},
#  '678f519f437a1200556491d0464a5a8271128e79': {'title': [],
#   'abstract': [89, 95]},
#  '61cfddf18fe67c9cd9dc7593f1d57ffd5ef830a3': {'title': [],
#   'abstract': [47, 89, 172]},
#  '94559c249d204110296c39ed4af2042cc4468e68': {'title': [2], 'abstract': []},
#  'cfa518214ab08410c429b1ae9a06d2bf128bf192': {'title': [6],
#   'abstract': [13, 136]},
#  '961e2156d523e3901c491cc2a1f65764c976fc44': {'title': [], 'abstract': [71]},
#  '47fd4f954513d48b32d90f3486e05255f513b054': {'title': [], 'abstract': [93]},
#  'b7784de5559cd506123f2aeb02d04964916ec153': {'title': [], 'abstract': [54]},
#  '47966b673a145dfba9880c207ab4e21d692ab563': {'title': [], 'abstract': [106]},
#  'bc69bf9c9bd0f7ea81bf2718cdd41e3b0f9be27a': {'title': [], 'abstract': [117]},
#  '9f840d4caf38f89bc17aa690fb2dd3839766c894': {'title': [],
#   'abstract': [48, 192]},
#  '432b2550bac4dd0b7efdb80b8d588e3f5c6a1004': {'title': [], 'abstract': [17]},
#  '8f46f291825caa786890ef224a28cf513f049799': {'title': [],
#   'abstract': [2, 47]},
#  '1bc6f0454f47193bed4c8d5f89915291a6059d3d': {'title': [], 'abstract': [140]},
#  '7234b026681e2952f4868e934af1ba1b49ea9019': {'title': [], 'abstract': [87]},
#  'ce3af88e1edbbaf3731873615d91fac175f338d0': {'title': [1], 'abstract': []},
#  '6581c0198b7e2d02d10fa2addc207a9e2541e4dd': {'title': [], 'abstract': [99]},
#  '388200729c3a0eb7578dea378e246db33ccff3d7': {'title': [14], 'abstract': []},
#  '2d5a3ebbb2af671fc3965617af7622f9a087b54c': {'title': [], 'abstract': [7]},
#  '60e8d2c3b5a5b0c7bf8719892b74d5f15142eb9b': {'title': [],
#   'abstract': [14, 66, 131]},
#  '6685a9bbd5002c9775f14d83ad2683b2f8bd2a4f': {'title': [], 'abstract': [55]},
#  '6a08ac8407310cac14e023121c2d3de8079b8401': {'title': [],
#   'abstract': [64, 91]},
#  '0d64a9177d52f5ba241454bd140b9d15cafd76ed': {'title': [13], 'abstract': []},
#  '37764d8566d3a726e19b629fb2a6e09abce54925': {'title': [],
#   'abstract': [13, 82, 108, 125]},
#  'd2bd1762b36119bee3bd39e720050ff522c56a59': {'title': [], 'abstract': [55]},
#  '7c4408c12c089038197feb4f339c31ba60b42891': {'title': [], 'abstract': [75]},
#  '56cde6d38867db37922f243d56141eee1f869273': {'title': [],
#   'abstract': [46, 213]},
#  '1114a78b1eaeffd8361629c787f47e9693e3a3e6': {'title': [],
#   'abstract': [50, 53, 93]},
#  'df4f589943867f2d555387d1011e3763992bf4e6': {'title': [12],
#   'abstract': [22, 29]},
#  'bbaba42023321e64b089c829cfdde7b589f7fb54': {'title': [],
#   'abstract': [95, 135]},
#  '8414bcdd8de21e8f76c0191dc9e41808772b16d7': {'title': [], 'abstract': [112]},
#  '8f0b5fbb978c93e6eab286c7f971e45beca8d632': {'title': [0], 'abstract': []},
#  '3e205820cdbf7b82fc220f7de945b241f265b98f': {'title': [4], 'abstract': [4]},
#  '509d146b3a981a2ae6670faeed2b68b512bd8cc0': {'title': [], 'abstract': [134]},
#  '67f977fe47c8193a2db4611c3fb49ff514dc7eae': {'title': [],
#   'abstract': [23, 38]},
#  'bc21302c6850418c9c55c197d739929919d4a436': {'title': [], 'abstract': [78]},
#  'a73eb1cdb89c31d00b67ea85dfa728a9d5af0cdd': {'title': [], 'abstract': [135]},
#  'd6e78069dbbb35592f013187ef3432286def8f18': {'title': [3], 'abstract': []},
#  'be2e44f4f455db958e41a5dcd80dfe302597dd66': {'title': [], 'abstract': [158]},
#  'ac02d97a842d0993de12a44605ea46ff19b4031f': {'title': [], 'abstract': [70]},
#  'efdf3ff9ae07a202c1968fb14a2a06dc2a89bdf4': {'title': [1], 'abstract': []},
#  'd3b322f2cdf3ff0d96d68cce1daff92573e0c6e7': {'title': [], 'abstract': [66]},
#  '5cd211e8f8644984f1a7d68225676cb20acf720c': {'title': [], 'abstract': [58]},
#  '94a96f64bd93ad91642fa04da09bb709a26ac277': {'title': [5],
#   'abstract': [61, 90]},
#  '15911ba97d890b70afdddf4e47f32f3295f7d6ab': {'title': [], 'abstract': [35]},
#  '74967c005ef606affce8c2861ec7aff27510f3d5': {'title': [], 'abstract': [64]},
#  'd6274aa862ff12fb97206e7cbf0c5bfeedb6e350': {'title': [], 'abstract': [145]},
#  '32e12d5a8a6cb7ac94d4cedf4a6e2fd3bc5156cb': {'title': [], 'abstract': [76]},
#  'a5fd9fdf860821039d43080fee1afb8b5d6b6996': {'title': [], 'abstract': [3]},
#  '8765c0fa48fe5a6384bfb650027282581a1ace97': {'title': [],
#   'abstract': [87, 92, 95, 99, 135]},
#  '524e7448d98590906ce890a7d6cd12c8bf5cc9eb': {'title': [],
#   'abstract': [35, 70]},
#  '89dba9b81d81b44f083cbfc97e78e8c69723a958': {'title': [], 'abstract': [2]},
#  ...}

# %% [markdown]
# ### 🔄 Dynamic Indexing
#
# To make the index dynamic, you’ll add capabilities for adding and removing individual documents.
#
# - **Add a Document**: Implement the `add_document()` function. It takes a tuple with the document ID, title, and abstract. If the document isn’t already in the index, it will be added.
# - **Remove a Document**: Implement the `remove_document()` function. It takes the document ID and removes the corresponding document from the index.
# - **Uniqueness**: Ensure that document IDs remain unique in the index. For instance, the same ID won’t be added twice unless it’s removed and re-added.

# %%
from pygtrie import StringTrie

def add_documnet(document : tuple):
    """Adds a document to positional index

    Parameters
    ----------
    document : str
        Comma separated string containing id,title,abstarct in this exact order
    """
    paper_id, title, abstract = document
    
    title_tokens = [t for t in clean_data(title) if t not in top_30_tokens.keys()]
    abstract_tokens = [t for t in clean_data(abstract) if t not in top_30_tokens.keys()]
    
    title_lengths[paper_id] = len(title_tokens)
    abstract_lengths[paper_id] = len(abstract_tokens)
    
    for i, token in enumerate(title_tokens):
        positional_index[token][paper_id]['title'].append(i)
        frequencies[token] += 1
    for i, token in enumerate(abstract_tokens):
        positional_index[token][paper_id]['abstract'].append(i)
        frequencies[token] += 1
    return

new_document = ("1eae26fe1ca566f17468080c3aecab1c3f9efb66", 
                "A Deep Learning Framework for Viable Tumor Burden Estimation", 
                "Liver masses have become a common clinical challenge since they require to be defined and accurately categorized as neoplastic or nonneoplastic lesions. Hepatocellular carcinoma (HCC), the most common histologic type of primary liver malignancy, is a global health concern being the fifth most common cancer and the second cause of cancer mortality worldwide. Accurate diagnosis, which in some circumstances requires histopathology results, is necessary for appropriate management. Also, some tumor characteristics help in predicting tumor behavior and patient response to therapy. In this paper, we propose a deep learning framework for the segmentation of whole and viable tumor areas of liver cancer from whole-slide images (WSIs). To this end, we use Fast Segmentation Convolutional Neural Network (Fast-SCNN) as our network. We use the dataset from PAIP 2019 challenge. After data-augmentation on the training subset, we train the network with a multi-term loss function and SWA technique. Our model achieves 0.80 for the median of the Jaccard Index for the task of Viable Tumor Segmentation and 0.77 for the median of Weighted Absolute Accuracy for the task of Viable Tumor Burden Estimation on the whole-slide images of the test subset.")
add_documnet(new_document)

# %%
def remove_document(document_id : str):
    """removes a document from positional index

    Parameters
    ----------
    document_id : str
        Id of the document
    """
    del title_lengths[document_id]
    del abstract_lengths[document_id]

    for token in list(positional_index.keys()):
        if document_id in positional_index[token]:
            token_doc_occurence = len(positional_index[token][document_id]['title']) + len(positional_index[token][document_id]['abstract'])
            del positional_index[token][document_id]
            frequencies[token] -= token_doc_occurence
    
        if not positional_index[token]:
            del positional_index[token]
        if not frequencies[token]:
            del frequencies[token]
    return

remove_document("1eae26fe1ca566f17468080c3aecab1c3f9efb66")

# %% [markdown]
# ### 💾 Index Compression & Storage
#
# In this section, you’ll add the ability to save and reload the index.
#
# - **Storage Methods**: Implement three methods for saving the index:
#   1. **No compression**
#   2. **Gamma-code compression**
#   3. **Variable-byte compression**
# - **Implementation**: You’ll implement these compression techniques yourself.
# - **File Format**: Save the index in JSON or TXT format. Name the file after the compression method used, and upload it in a zip file.
# - **Scoring**: Part of your score here depends on the efficiency of your compression.
#
# - **Load the Index**: Implement the `load_index(path)` function, which reloads the index from a saved file.

# %% [markdown]
# ## Variable-Byte Method

# %%
import json

def encode_vbyte(num):
    bytes_list = []
    while num > 127:
        bytes_list.append(num & 127)
        num >>= 7
    bytes_list.append(num | 128)
    return bytearray(bytes_list)


def decode_vbyte(bytearray_data):
    num = 0
    for i, byte in enumerate(bytearray_data):
        if byte < 128:
            num |= byte << (7 * i)
            break
        num |= (byte & 127) << (7 * i)
    return num


def convert_gapped_to_list(gapped_arr):
    arr = []
    last_index = 0
    for i in gapped_arr:
        decoded = decode_vbyte(bytes.fromhex(i))
        arr.append(decoded + last_index)
        last_index = decoded
    return arr
        
    return gaps_arr


def convert_list_to_gaps(arr):
    gaps_arr = []
    last_index = 0
    for i in arr:
        gaps_arr.append(i - last_index)
        last_index = i
        
    return gaps_arr

def vb_encode_arr(arr):
    encoded_arr = []
    for i in arr:
        encoded_arr.append(encode_vbyte(i))
    
    return encoded_arr

def get_vb_encoded_positional_index(positional_index):
    encoded_pi = defaultdict(lambda: defaultdict(lambda: {'title': [], 'abstract': []}))
    for token, papers in positional_index.items():
        for paper_id, data in papers.items():
            title_positions = data['title']
            abstarct_positions = data['abstract']
            gaps_title_positions = convert_list_to_gaps(title_positions)
            gaps_abstract_positions = convert_list_to_gaps(abstarct_positions)
            encoded_title_positions = vb_encode_arr(gaps_title_positions)            
            encoded_abstract_positions = vb_encode_arr(gaps_abstract_positions)
            encoded_pi[token][paper_id]['title'] = encoded_title_positions
            encoded_pi[token][paper_id]['abstract'] = encoded_abstract_positions
    
    return encoded_pi

def convert_gapped_positional_index_to_normal(encoded_pi):
    positional_index = defaultdict(lambda: defaultdict(lambda: {'title': [], 'abstract': []}))
    for token, papers in encoded_pi.items():
        for paper_id, data in papers.items():
            gapped_title_positions = data['title']
            gapped_abstarct_positions = data['abstract']
            title_positions = convert_gapped_to_list(gapped_title_positions)
            abstract_positions = convert_gapped_to_list(gapped_abstarct_positions)
            positional_index[token][paper_id]['title'] = title_positions
            positional_index[token][paper_id]['abstract'] = abstract_positions
            
    return positional_index

class ByteArrayEncoder(json.JSONEncoder):
    def default(self, obj):
        if isinstance(obj, bytearray):
            return obj.hex()
        return json.JSONEncoder.default(self, obj)

# %% [markdown]
# ## Gamma-Codes

# %%
def encode_gamma(num):
    """Encode an integer using Gamma codes method"""
    if num == 0:
        return "0"
    binary = bin(num)[2:]
    offset = "0" * (len(binary) - 1)
    return offset + binary

def decode_gamma(gamma_code):
    """Decode an integer encoded with Gamma codes method"""
    i = 0
    while gamma_code[i] == "0":
        i += 1
        if i == len(gamma_code):
            break
    binary = "1" + gamma_code[i+1:i*2+1]
    return int(binary, 2)



def convert_gamma_gapped_to_list(gapped_arr):
    arr = []
    last_index = 0
    for i in gapped_arr:
        decoded = decode_gamma(i)
        arr.append(decoded + last_index)
        last_index = decoded
    return arr
        
    return gaps_arr


def gamma_encode_arr(arr):
    encoded_arr = []
    for i in arr:
        encoded_arr.append(encode_gamma(int(i)))
    
    return encoded_arr

def get_gamma_encoded_positional_index(positional_index):
    encoded_pi = defaultdict(lambda: defaultdict(lambda: {'title': [], 'abstract': []}))
    for token, papers in positional_index.items():
        for paper_id, data in papers.items():
            title_positions = data['title']
            abstarct_positions = data['abstract']
            gaps_title_positions = convert_list_to_gaps(title_positions)
            gaps_abstract_positions = convert_list_to_gaps(abstarct_positions)
            encoded_title_positions = gamma_encode_arr(gaps_title_positions)            
            encoded_abstract_positions = gamma_encode_arr(gaps_abstract_positions)
            encoded_pi[token][paper_id]['title'] = encoded_title_positions
            encoded_pi[token][paper_id]['abstract'] = encoded_abstract_positions
    
    return encoded_pi


def gamma_convert_gapped_positional_index_to_normal(encoded_pi):
    positional_index = defaultdict(lambda: defaultdict(lambda: {'title': [], 'abstract': []}))
    for token, papers in encoded_pi.items():
        for paper_id, data in papers.items():
            gapped_title_positions = data['title']
            gapped_abstarct_positions = data['abstract']
            title_positions = convert_gamma_gapped_to_list(gapped_title_positions)
            abstract_positions = convert_gamma_gapped_to_list(gapped_abstarct_positions)
            positional_index[token][paper_id]['title'] = title_positions
            positional_index[token][paper_id]['abstract'] = abstract_positions
            
    return positional_index

# %%
import os
import json

def store_index(path: str, compression_type: str):
    """Stores the index in a file

    Parameters
    ----------
    path : str
        Path to store the file

    compression_type : str
        Could be one of the followings:
        - no-compression
        - gamma-code
        - variable-byte

    Returns
    int
        The size of the stored file
    """
    if compression_type == 'no-compression':
        with open(path, 'w') as f:
            json.dump(positional_index, f)

    if compression_type == 'gamma-code':
        encoded_positional_index = get_gamma_encoded_positional_index(positional_index)
        with open(path, 'w') as f:
            json.dump(encoded_positional_index, f)

    if compression_type == 'variable-byte':
        encoded_positional_index = get_vb_encoded_positional_index(positional_index)
        with open(path, 'w') as f:
            json.dump(encoded_positional_index, f, cls=ByteArrayEncoder)

    size_of_file = os.path.getsize(path)
    return size_of_file

store_index("/home/alireza/Desktop/index.json", "no-compression")
# Out:
# 31019882

# %%
def load_index(path: str, compression_type: str):
    """Loads the index from a file

    Parameters
    ----------
    path : str
        Path of the file to load from

    compression_type : str
        Could be one of the followings:
        - no-compression
        - gamma-code
        - variable-byte
    """
    positional_index = None
    if compression_type == 'no-compression':
        with open(path, 'r') as f:
            positional_index = json.load(f)
    if compression_type == 'gamma-code':
        encoded_positional_index = None
        with open(path, 'r') as f:
            encoded_positional_index = json.load(f)
            positional_index = gamma_convert_gapped_positional_index_to_normal(encoded_positional_index)
    
    if compression_type == 'variable-byte':
        encoded_positional_index = None
        with open(path, 'r') as f:
            encoded_positional_index = json.load(f)
            positional_index = convert_gapped_positional_index_to_normal(encoded_positional_index)

    return positional_index

positional_index = load_index("/home/alireza/Desktop/index.json", "no-compression")

# %% [markdown]
# ### 🔄 Spell Correction
#
# If the user query contains spelling mistakes or words not found in the dictionary, your system should correct the query.
#
# - **Bigram Extraction**: First, generate bigrams from the word.
# - **Jaccard Similarity**: Find the top 20 words with the most common bigrams using Jaccard similarity.
# - **Edit Distance**: Finally, use the minimum edit distance to find the best replacement word.
#
# - **Note**: There’s no need to store or compress the bigram index. You can use existing code for calculating edit distance.

# %%
import nltk
from nltk.util import ngrams
from typing import List, Dict
import itertools


def create_bigram_index(texts: List[str]) -> Dict[str, List[str]]:
    """
    Creates a bigram index for the spell correction

    Parameters
    ----------
    texts: List[str]
        The titles and abstracts of articles

    Returns
    -------
    dict
        A dictionary of bigrams and their occurence
    """
    bigram: Dict[str, List[str]] = {}
    
    texts = [sentence.lower().split() for sentence in texts]
    tokens = list(itertools.chain(*texts))

    # TODO: Create the bigram index here
    for token in tokens:
        token = token.lower()
        token = "".join(char for char in token if char.isalnum())

        ngrams_list = list(ngrams(token, 2))
        for ngram in ngrams_list:
            if ngram not in bigram:
                bigram[ngram] = set()
            bigram[ngram].add(token)
    return bigram

bigram_index = create_bigram_index(all_data)

# %%
from nltk import ngrams
from nltk.metrics import jaccard_distance, edit_distance

def correct_text(input_word: str, similar_words_limit: int=20) -> str:
    """
    Correct the give query text, if it is misspelled

    Paramters
    ---------
    text: str
        The query text
    
    Returns
    str
        The corrected form of the given text
    """
    corrected_text = ""

    # TODO: Correct the text here
    input_bigrams = set(ngrams(input_word.lower(), 2))
    
    similarities = []
    for bigram in input_bigrams:
        if bigram in bigram_index:
            for word in bigram_index[bigram]:
                similarity = 1 - jaccard_distance(input_bigrams, set(ngrams(word.lower(), 2)))
                similarities.append((word, similarity))
    
    similarities.sort(key=lambda x: x[1], reverse=True)
    similar_words = [word[0] for word in similarities[:20]]
    
    try:
        corrected_word = min(similar_words, key=lambda x: edit_distance(input_word.lower(), x))
    except Exception as e:
        return [], None
    return corrected_word

corrected_word = correct_text('dep')
print(corrected_word)
# Out:
# deep

# %% [markdown]
# ### 🔍 Search and Document Retrieval
#
# In this section, you’ll implement the search functionality to retrieve documents based on a user query.
#
# - **Search Scope**: The search should be conducted across both the title and abstract of documents.
# - **Result Ranking**: Documents should be returned in order of their final scores. This score is a weighted sum of the title and abstract search scores.
#
# - **Search Methods**:
#   1. **TF-IDF (ltn-lnn and ltc-lnc variants)**: Implement these methods in vector space for ranked retrieval.
#   2. **Probabilistic Retrieval (Okapi BM25)**: Implement this for probabilistic document retrieval.
#
# - **Final Score Calculation**:
#   - Use the formula:
#     `final score = weight * abstract_score + (1 - weight) * title_score`
#   - The `weight` is a number between 0 and 1. If it’s 0, the title score is ignored, and vice versa.
#
# - **Function `search(query, method, n, mode, where)`**:
#   - **Input**: The search query, scoring method, number of documents to return, mode (whether to search title and abstract separately), and where (which part to search if only one).
#   - **Output**: If `print=True`, return a readable list of documents with snippets.

# %%
def _spell_correct_query(query: str):
    splitted_lower_query = [word for word in query.lower().split() if word not in top_30_tokens]
    corrected_query_words = [correct_text(word) for word in splitted_lower_query]
    return " ".join(corrected_query_words)

def preprocess_query(query: str):
    corrected_query = _spell_correct_query(query)
    tokenized_query = [token for token in clean_data(corrected_query) if token not in top_30_tokens]
    return tokenized_query

# %%
import math

number_of_documents = len(corpus)
def get_idf(token, prob=False):
    df = len(positional_index[token])
    if prob:
        return max(0, math.log10((number_of_documents - df) / (df + 1)))
    else:
        return math.log10(number_of_documents / (df + 1))

def get_logarithmic_tf(tf_raw):
    if tf_raw == 0:
        return 0
    else:
        return 1 + math.log10(tf_raw)

# %%
import re


import nltk
from nltk.stem import WordNetLemmatizer
from nltk.corpus import wordnet

def tokenize_without_change(text):
    # Tokenize the text
    tokens = nltk.word_tokenize(text)
    tokens = [t.lower() for t in tokens if t.isalpha()]
    lemmatizer = WordNetLemmatizer()
    tokens = [lemmatizer.lemmatize(t) for t in tokens]
    return tokens

def get_snippet(query, content):
    query_tokens = tokenize_without_change(query)
    content_tokens = tokenize_without_change(content)

    query_start_index = -1
    for i in range(len(content_tokens) - len(query_tokens) + 1):
        if content_tokens[i:i+len(query_tokens)] == query_tokens:
            query_start_index = i
            break

    if query_start_index == -1:
        return ' '.join(content_tokens[:20])

    start_index = max(0, query_start_index - 10)
    end_index = min(len(content_tokens), query_start_index + 10 + len(query_tokens))

    snippet_tokens = content_tokens[start_index:end_index]
    snippet = ' '.join(snippet_tokens)

    return snippet

def print_result(doc_ids, title_query, abstract_query):
    corrected_title_query = _spell_correct_query(title_query)
    abstract_query = _spell_correct_query(abstract_query)

    print('________________________________')
    for doc_id in doc_ids:
        print()
        title_content = all_titles[doc_id]
        abstract_content = all_abstracts[doc_id]
        title_snippet = get_snippet(title_query, title_content)
        abstract_snippet = get_snippet(abstract_query, abstract_content)
        print(f"Paper Id: {doc_id}")
        print(f'Title Snippet: {title_snippet}')
        print(f'Abstract Snippet: {abstract_snippet}')
        print('________________________________')

# %%
def get_doc_scores(tf_query, method, field='title'):
    doc_scores = defaultdict(int)
    norm_factors = defaultdict(int)

    doc_lengths = title_lengths if field == 'title' else abstract_lengths
    average_doc_length = sum([v for v in doc_lengths.values()]) / len(doc_lengths)
    for token, tf_query_raw in tf_query.items():
        if token not in positional_index:
            continue
        for doc_id, positions in positional_index[token].items():
            if len(positions[field]) == 0:
                continue
            if method == 'ltn-lnn':
                tf_doc_raw = len(positions.get(field, []))
                tf_doc = get_logarithmic_tf(tf_doc_raw)
                idf = get_idf(token)
                doc_coeff = idf * tf_doc
                
                tf_query = get_logarithmic_tf(tf_query_raw)
                doc_scores[doc_id] += tf_query * doc_coeff
                
            if method == 'ltc-lnc':
                tf_doc_raw = len(positions.get(field, []))
                tf_doc = get_logarithmic_tf(tf_doc_raw)
                idf = get_idf(token)
                doc_coeff = idf * tf_doc
                tf_query = get_logarithmic_tf(tf_query_raw)

                doc_scores[doc_id] += tf_query * doc_coeff
                norm_factors[doc_id] += doc_coeff ** 2
            if method == 'okapi25':
                k1 = 1.5
                b = 0.75
                tf_token_doc = len(positions.get(field, []))
                doc_scores[doc_id] += get_idf(token) * (k1 + 1) * tf_token_doc / (k1 * (1 - b + b * doc_lengths[doc_id] / average_doc_length) + tf_token_doc)
    
    if method == 'ltc-lnc':
        for doc_id in doc_scores:
            doc_scores[doc_id] /= math.sqrt(norm_factors[doc_id])
    
    return doc_scores

# %%
import collections

from typing import List, Tuple

def search(title_query: str, abstract_query: str, max_result_count: int, method: str = 'ltn-lnn', weight: float = 0.5, print=False):
    """
        Finds relevant documents to query
        
        Parameters
        ---------------------------------------------------------------------------------------------------
        max_result_count: Return top 'max_result_count' docs which have the highest scores. 
                          notice that if max_result_count = -1, then you have to return all docs
        
        mode: 'detailed' for searching in title and text separately.
              'overall' for all words, and weighted by where the word apears on.
        
        where: when mode ='detailed', when we want search query 
                in title or text not both of them at the same time.
        
        method: 'ltn-lnn' or 'ltc-lnc' or 'okapi25'

        Returns
        ----------------------------------------------------------------------------------------------------
        list
        Retreived documents with snippet
    """
    # TODO: retun top 'max_result_count' documents for your searched query
    tf_query_title = defaultdict(int)
    tf_query_abstract = defaultdict(int)
    
    tokens_title = preprocess_query(title_query) if title_query else []
    tokens_abstract = preprocess_query(abstract_query) if abstract_query else []
    query_tokens = tokens_title + tokens_abstract

    scores = collections.defaultdict(list)
    for token in tokens_title:
        tf_query_title[token] += 1
            
    for token in tokens_abstract:
        tf_query_abstract[token] += 1
    
    
    title_query_doc_scores = get_doc_scores(tf_query_title, method, 'title')
    abstract_query_doc_scores = get_doc_scores(tf_query_abstract, method, 'abstract')
    
    total_doc_ids = list(set(list(title_query_doc_scores.keys()) + list(abstract_query_doc_scores.keys())))
    doc_scores = collections.defaultdict(int)
    
    for doc_id in total_doc_ids:
        title_score = title_query_doc_scores.get(doc_id, 0)
        abstract_score = abstract_query_doc_scores.get(doc_id, 0)
        
        doc_scores[doc_id] = weight * title_score + (1 - weight) * abstract_score
        
    sorted_doc_ids = [key for key, value in sorted(doc_scores.items(), key=lambda item: item[1], reverse=True)]
    applicable_doc_ids = sorted_doc_ids[:max_result_count]
    if print:
        print_result(applicable_doc_ids, title_query, abstract_query)
    return applicable_doc_ids
results = search('Translation Model Based on Deep Learning','Translation Model Based on Deep Learning', 10, method='ltc-lnc', print=True)
# Out:
# ________________________________
#
# Paper Id: 20f77d34ab1aec7d0a6e613a740aff7ec7fbf55a
# Title Snippet: a machine translation framework based on neural network deep learning from semantics to feature analysis
# Abstract Snippet: this paper us an framework based on semantic to feature analysis to construct a neural machine translation model let the
# ________________________________
#
# Paper Id: 0ca95a34c0a59132e7f0925b189de884e51a93a6
# Title Snippet: design of intelligent recognition english translation model based on deep learning
# Abstract Snippet: nowadays the intercommunication and translation of global language ha become an indispensable condition for friendly communication among human being around
# ________________________________
#
# Paper Id: 1167a9431e3743e16ab7e38bf60bdf63a278f7e9
# Title Snippet: english translation model based on intelligent recognition and deep learning
# Abstract Snippet: aiming at the problem of low accuracy of english phrase part of speech recognition poor english translation effect and long
# ________________________________
#
# Paper Id: 2c88c3d8bc68858e4c9ba58ec3d71454e94eb96e
# Title Snippet: analysis of chinese machine translation training based on deep learning technology
# Abstract Snippet: with the advent of the information age people can establish good communication through internet technology mechanical translation ha become a
# ________________________________
#
# Paper Id: 9cc8609f904c50b1be408abede7ab7f5cdbc9744
# Title Snippet: research on machine translation of deep neural network learning model based on ontology
# Abstract Snippet: to align different ontology it is necessary to find effective way to achieve interoperability of information in the context of
# ________________________________
#
# Paper Id: f29df408f1407c60b0f85dd595a883de7c66e763
# Title Snippet: research machine translation based on deep learning
# Abstract Snippet: urdu is pakistan national language however chinese expertise is very negligible in pakistan and the asian nation yet fewer research
# ________________________________
#
# Paper Id: 5c6199859eb8b4ebd4188c6587f6ad8e6448a983
# Title Snippet: design concept of sign language recognition translation and gesture recognition control system based on deep learning and machine vision
# Abstract Snippet: with the development of society gesture are used in many aspect but the computer functionality for gesture recognition is still
# ________________________________
#
# Paper Id: 864e033c002c5ec48d4c273c53ce995682fc3e21
# Title Snippet: deep learning machine learning for chinese and japanese translation
# Abstract Snippet: this paper take deep learning a the background of researcher design combine the relevant research result in recent year address
# ________________________________
#
# Paper Id: 28293e2b07acccc222f5b0deca15105430759a92
# Title Snippet: seismic facies analysis based on deep learning
# Abstract Snippet: seismic facies analysis is to study the sedimentary environment of stratigraphic sequence and provides an important basis for reservoir prediction
# ________________________________
#
# Paper Id: bbf052271c70dd926cd230bb5640cdcdfeccf1cc
# Title Snippet: accuracy analysis of japanese machine translation based on machine learning and image feature retrieval
# Abstract Snippet: at present there are still many deficiency in machine translation method the processing of corpus information is not deep enough
# ________________________________

# %% [markdown]
# ### 🧪 Evaluation
#
# This section focuses on evaluating the system's performance using a validation set.
#
# - **Validation Data**: You’re provided with sample queries and their corresponding documents in a validation file. Each query has the necessary details for creation.
# - **Process**:
#   - Generate queries based on the provided information.
#   - Treat the results as `predicted results`.
#   - The provided list of IDs will be your `actual results`.
#
# - **Metrics**:
#   - Implement the following evaluation metrics (without using pre-built functions):
#   - Report these metrics for each query and overall.
#       - MRR (Mean Reciprocal Rank)
#       - Precision
#       - Recall
#       - F1 Score
#       - MAP (Mean Average Precision)
#       - NDCG (Normalized Discounted Cumulative Gain)

# %%
import json

def read_json_file(file_path):
    with open(file_path, 'r') as f:
        data = json.load(f)
    return data
query_ground_truth = read_json_file('./AI & Bioinformatics/validation.json')

# %%
from typing import List


def calculate_precision(actual: List[List[str]], predicted: List[List[str]]) -> float:
    """
    Calculates the precision of the predicted results

    Parameters
    ----------
    actual : List[List[str]]
        The actual results
    predicted : List[List[str]]
        The predicted results

    Returns
    -------
    float
        The precision of the predicted results
    """
    precision = 0.0

    # TODO: Calculate precision here
    num_retrieved = 0
    num_relevant = 0
    
    for i in range(len(actual)):
        actual_set = set(actual[i])
        retrieved_set = set(predicted[i])
        
        num_retrieved += len(retrieved_set)
        num_relevant += len(actual_set.intersection(retrieved_set))
    
    if num_retrieved == 0:
        precision = 0.0
    else:
        precision = num_relevant / num_retrieved
    
    return precision

# %%
def calculate_recall(actual: List[List[str]], predicted: List[List[str]]) -> float:
    """
    Calculates the recall of the predicted results

    Parameters
    ----------
    actual : List[List[str]]
        The actual results
    predicted : List[List[str]]
        The predicted results

    Returns
    -------
    float
        The recall of the predicted results
    """
    num_retrieved = 0
    num_relevant = 0
    
    for i in range(len(actual)):
        actual_set = set(actual[i])
        retrieved_set = set(predicted[i])
        
        num_retrieved += len(retrieved_set)
        num_relevant += len(actual_set.intersection(retrieved_set))
    
    if num_relevant == 0:
        recall = 0.0
    else:
        recall = num_relevant / sum(len(docs) for docs in actual_docs)
    
    return recall

# %%
def calculate_F1(actual: List[List[str]], predicted: List[List[str]]) -> float:
    """
    Calculates the F1 score of the predicted results

    Parameters
    ----------
    actual : List[List[str]]
        The actual results
    predicted : List[List[str]]
        The predicted results

    Returns
    -------
    float
        The F1 score of the predicted results    
    """
    f1 = 0.0

    # TODO: Calculate F1 here
    precision = calculate_precision(actual, predicted)
    recall = calculate_recall(actual, predicted)

    f1 = 2 * precision * recall / (precision + recall) if precision + recall > 0 else 0
    return f1

# %%
def calculate_MAP(actual: List[List[str]], predicted: List[List[str]]) -> float:
    """
    Calculates the Mean Average Precision of the predicted results

    Parameters
    ----------
    actual : List[List[str]]
        The actual results
    predicted : List[List[str]]
        The predicted results

    Returns
    -------
    float
        The Mean Average Precision of the predicted results
    """
    
    def average_precision(actual, predicted):
        precision = []
        relevant_count = 0
        for i, item in enumerate(predicted):
            if item in actual:
                relevant_count += 1
                precision.append(relevant_count / (i + 1))
        if len(precision) == 0:
            return 0
        return sum(precision) / len(precision)

    ap = []
    for actual_i, predicted_i in zip(actual, predicted):
        ap.append(average_precision(actual_i, predicted_i))
    return sum(ap) / len(ap)

# %%
import numpy as np
def cacluate_NDCG(actual: List[List[str]], predicted: List[List[str]]) -> float:
    """
    Calculates the Normalized Discounted Cumulative Gain (NDCG) of the predicted results

    Parameters
    ----------
    actual : List[List[str]]
        The actual results
    predicted : List[List[str]]
        The predicted results

    Returns
    -------
    float
        The NDCG of the predicted results
    """
    ndcg = 0.0
    k = 10
    for actual_i, predicted_i in zip(actual, predicted):
        if k is not None:
            actual_i = actual_i[:k]
            predicted_i = predicted_i[:k]
        rel = [1 if item in actual_i else 0 for item in predicted_i]
        dcg = np.sum((2**np.asarray(rel) - 1) / np.log2(np.arange(2, len(rel) + 2)))
        idcg = np.sum((2**np.sort(rel)[::-1] - 1) / np.log2(np.arange(2, len(rel) + 2)))
        ndcg += dcg / idcg
    return ndcg / len(actual)
    return ndcg_score

# %%
def cacluate_MRR(actual: List[List[str]], predicted: List[List[str]]) -> float:
    """
    Calculates the Mean Reciprocal Rank of the predicted results

    Parameters
    ----------
    actual : List[List[str]]
        The actual results
    predicted : List[List[str]]
        The predicted results

    Returns
    -------
    float
        The MRR of the predicted results
    """
    mrr_score = 0.0
    num_queries = len(actual)
    
    for i in range(num_queries):
        query_actual_docs = set(actual[i])
        query_retrieved_docs = predicted[i]
        num_retrieved = len(query_retrieved_docs)
        
        for j in range(num_retrieved):
            if query_retrieved_docs[j] in query_actual_docs:
                mrr_score += 1.0 / (j+1)
                break
    
    mrr_score /= num_queries
    
    return mrr_score

# %%
actual_docs = list(query_ground_truth.values())
queries = list(query_ground_truth.keys())

def predict(queries, method, weight=0.5):
    predicted = []
    for query in queries:
        predicted.append(
            search(
                query,
                query,
                10,
                weight=weight,
                method=method,
            )
        )
    return predicted

# %%
# TODO: Call evaluation functions here and report the results for ltn.lnn
ltn_lnn_predicted = predict(queries, 'ltn-lnn')

print(f"ltn.lnn precision = {calculate_precision(actual_docs, ltn_lnn_predicted)}")
print(f"ltn.lnn recall = {calculate_recall(actual_docs, ltn_lnn_predicted)}")
print(f"ltn.lnn F1 = {calculate_F1(actual_docs, ltn_lnn_predicted)}")
print(f"ltn.lnn MAP = {calculate_MAP(actual_docs, ltn_lnn_predicted)}")
print(f"ltn.lnn NDCG = {cacluate_NDCG(actual_docs, ltn_lnn_predicted)}")
print(f"ltn.lnn MRR = {cacluate_MRR(actual_docs, ltn_lnn_predicted)}")
# Out:
# ltn.lnn precision = 0.6
# ltn.lnn recall = 0.6
# ltn.lnn F1 = 0.6
# ltn.lnn MAP = 0.7147791215251532
# ltn.lnn NDCG = 0.8026826478824044
# ltn.lnn MRR = 0.7321428571428571

# %%
# TODO: Call evaluation functions here and report the results for ltc.lnc
ltc_lnc_predicted = predict(queries, 'ltc-lnc')

print(f"ltc.lnc precision = {calculate_precision(actual_docs, ltc_lnc_predicted)}")
print(f"ltc.lnc recall = {calculate_recall(actual_docs, ltc_lnc_predicted)}")
print(f"ltc.lnc F1 = {calculate_F1(actual_docs, ltc_lnc_predicted)}")
print(f"ltc.lnc MAP = {calculate_MAP(actual_docs, ltc_lnc_predicted)}")
print(f"ltc.lnc NDCG = {cacluate_NDCG(actual_docs, ltc_lnc_predicted)}")
print(f"ltc.lnc MRR = {cacluate_MRR(actual_docs, ltc_lnc_predicted)}")
# Out:
# ltc.lnc precision = 0.7
# ltc.lnc recall = 0.7
# ltc.lnc F1 = 0.7
# ltc.lnc MAP = 0.8688964474678761
# ltc.lnc NDCG = 0.9289264934141447
# ltc.lnc MRR = 0.9166666666666666

# %%
# TODO: Call evaluation functions here and report the results for Okapi BM25
okapi25_predicted = predict(queries, 'okapi25')

print(f"Okapi BM25 precision = {calculate_precision(actual_docs, okapi25_predicted)}")
print(f"Okapi BM25 recall = {calculate_recall(actual_docs, okapi25_predicted)}")
print(f"Okapi BM25 F1 = {calculate_F1(actual_docs, okapi25_predicted)}")
print(f"Okapi BM25 MAP = {calculate_MAP(actual_docs, okapi25_predicted)}")
print(f"Okapi BM25 NDCG = {cacluate_NDCG(actual_docs, okapi25_predicted)}")
print(f"Okapi BM25 MRR = {cacluate_MRR(actual_docs, okapi25_predicted)}")
# Out:
# Okapi BM25 precision = 0.65
# Okapi BM25 recall = 0.65
# Okapi BM25 F1 = 0.65
# Okapi BM25 MAP = 0.720045325228857
# Okapi BM25 NDCG = 0.8169236925370013
# Okapi BM25 MRR = 0.75
